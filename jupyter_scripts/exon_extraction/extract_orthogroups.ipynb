# %%
import pandas as pd

# %%
import re

# %%
df = pd.read_csv('Orthogroups.tsv', sep='\t', low_memory=False)

# %%
species = pd.read_csv('important_species_list.txt', header=None)
species_list = species[0].tolist()

# %%
print(species_list)
# Out:
# ['Acyrthosiphon_pisum', 'Aedes_aegypti', 'Drosophila_mojavensis', 'Bombyx_mori', 'Helicoverpa_armigera', 'Apis_mellifera', 'Blattella_germanica', 'Gryllus_bimaculatus', 'Tribolium_castaneum']

# %%
# 生成正则匹配模式（忽略大小写，并允许部分匹配）
species_pattern = "|".join(species_list)  # 组合成正则表达式 'Actias_luna|Adoxophyes_honmai|...'

# %%
# 找到所有匹配的列（第一列始终保留）
cols_to_keep = [df.columns[0]] + [col for col in df.columns if re.search(species_pattern, col, re.IGNORECASE)]

# %%
# 生成提取后的 DataFrame
df_filtered = df[cols_to_keep]

# %%
df_filtered = df_filtered.copy()
df_filtered.drop("Bombyx_mori.protein", axis=1, inplace=True)
df_filtered.rename(columns={"Bombyx_mori_new.protein": "Bombyx_mori.protein"}, inplace=True)

# %%
df_filtered.columns = df_filtered.columns.str.replace(r'\.protein', '', regex=True)

# %%
print(df_filtered)
# Out:
#        Orthogroup                                Acyrthosiphon_pisum  \
# 0       OG0000000  XM_008179938.1, XM_008179973.1, XM_008180018.1...
# 1       OG0000001  XM_008183679.1, XM_008184658.3, XM_008189338.1...
# 2       OG0000002  XM_003241194.1, XM_003245210.4, XM_008180012.1...
# 3       OG0000003  XM_003243647.1, XM_003243710.2, XM_003244376.2...
# 4       OG0000004  XM_008181907.1, XM_008181926.1, XM_008181927.1...
# ...           ...                                                ...
# 280541  OG0280541                                                NaN
# 280542  OG0280542                                                NaN
# 280543  OG0280543                                                NaN
# 280544  OG0280544                                                NaN
# 280545  OG0280545                                                NaN
#
#                                             Aedes_aegypti Apis_mellifera  \
# 0       g10265.t1, g10290.t1, g10291.t1, g10875.t1, g1...            NaN
# 1       g10332.t1, g10333.t1, g10387.t1, g10388.t1, g1...            NaN
# 2       g10284.t1, g10909.t1, g10977.t1, g11165.t1, g1...            NaN
# 3       g10428.t1, g11276.t1, g11639.t1, g13146.t1, g1...            NaN
# 4       g1059.t1, g10634.t1, g10636.t1, g10637.t1, g10...            NaN
# ...                                                   ...            ...
# 280541                                                NaN            NaN
# 280542                                                NaN            NaN
# 280543                                                NaN            NaN
# 280544                                                NaN            NaN
# 280545                                                NaN            NaN
#
#                                       Blattella_germanica  \
# 0       Bger003899.1, Bger012068.1, Bger014673.1, Bger...
# 1       Bger000006.1, Bger000473.1, Bger000741.1, Bger...
# 2       Bger004059.1, Bger013191.1, Bger016483.1, Bger...
# 3       Bger000048.1, Bger000138.1, Bger000140.1, Bger...
# 4       Bger000737.1, Bger000881.1, Bger001020.1, Bger...
# ...                                                   ...
# 280541                                                NaN
# 280542                                                NaN
# 280543                                                NaN
# 280544                                                NaN
# 280545                                                NaN
#
#                                     Drosophila_mojavensis  \
# 0       XM_032729213.2, XM_032730304.2, XM_032733225.2...
# 1                                          XM_044009142.1
# 2       XM_032733052.2, XM_044007873.1, XM_044009374.1...
# 3                                                     NaN
# 4          XM_044007123.1, XM_044010331.1, XM_044010353.1
# ...                                                   ...
# 280541                                                NaN
# 280542                                                NaN
# 280543                                                NaN
# 280544                                                NaN
# 280545                                                NaN
#
#                                       Gryllus_bimaculatus  \
# 0                                                     NaN
# 1       unassigned_transcript_21577, unassigned_transc...
# 2       unassigned_transcript_13262, unassigned_transc...
# 3       unassigned_transcript_14878, unassigned_transc...
# 4                             unassigned_transcript_20911
# ...                                                   ...
# 280541                                                NaN
# 280542                                                NaN
# 280543                                                NaN
# 280544                                                NaN
# 280545                                                NaN
#
#                                      Helicoverpa_armigera  \
# 0       Harm000031.1, Harm000037.1, Harm000524.1, Harm...
# 1       Harm003907.1, Harm003912.1, Harm011590.1, Harm...
# 2       Harm000857.1, Harm006004.1, Harm006103.1, Harm...
# 3       Harm000594.1, Harm000741.1, Harm000851.1, Harm...
# 4       Harm002765.1, Harm004384.1, Harm006313.1, Harm...
# ...                                                   ...
# 280541                                                NaN
# 280542                                                NaN
# 280543                                                NaN
# 280544                                                NaN
# 280545                                                NaN
#
#                                       Tribolium_castaneum  \
# 0       XM_064356887.1, XM_064358031.1, XM_064358855.1...
# 1       XM_008196330.3, XM_008203236.3, XM_064354770.1...
# 2       XM_001810026.1, XM_008193681.3, XM_008193682.3...
# 3                                                     NaN
# 4          XM_064354766.1, XM_064358034.1, XM_064358036.1
# ...                                                   ...
# 280541                                                NaN
# 280542                                                NaN
# 280543                                                NaN
# 280544                                                NaN
# 280545                                                NaN
#
#                                               Bombyx_mori
# 0       XM_004930167.5, XM_004934113.5, XM_004934284.2...
# 1       XM_004933773.5, XM_021348530.3, XM_038011536.2...
# 2       XM_012691466.4, XM_021348769.3, XM_021353027.2...
# 3       XM_004926346.2, XM_004926774.5, XM_004931210.2...
# 4       XM_004921625.2, XM_004925445.2, XM_012693465.1...
# ...                                                   ...
# 280541                     NM_001146241.1, XM_038017920.2
# 280542                     XM_038011851.2, XM_062668998.1
# 280543                     XM_062675580.1, XM_062675581.1
# 280544                     XM_021347894.3, XM_021347895.3
# 280545                     XM_062676981.1, XM_062677000.1
#
# [280546 rows x 10 columns]

# %%
gene_columns = df_filtered.columns

# %%
print(gene_columns)
# Out:
# Index(['Orthogroup', 'Acyrthosiphon_pisum', 'Aedes_aegypti', 'Apis_mellifera',
#        'Blattella_germanica', 'Drosophila_mojavensis', 'Gryllus_bimaculatus',
#        'Helicoverpa_armigera', 'Tribolium_castaneum', 'Bombyx_mori'],
#       dtype='object')

# %%
def count_gene_ids(cell):
    """
    统计单元格中基因ID的数量：
      - 对于空值返回 0
      - 按','拆分后，去除前后空格和空字符串，再统计数量
    """
    if pd.isnull(cell):
        return 0
    # 将 cell 转为字符串（防止非字符串类型），按','拆分
    # 使用 strip() 去除可能的空白字符，并过滤掉空串
    ids = [gene.strip() for gene in str(cell).split(',') if gene.strip()]
    return len(ids)

# %%
counts_df = df_filtered[gene_columns].map(count_gene_ids)

# %%
print(counts_df)
# Out:
#         Orthogroup  Acyrthosiphon_pisum  Aedes_aegypti  Apis_mellifera  \
# 0                1                  333            358               0
# 1                1                   26            238               0
# 2                1                   81            178               0
# 3                1                   74            264               0
# 4                1                   30            125               0
# ...            ...                  ...            ...             ...
# 280541           1                    0              0               0
# 280542           1                    0              0               0
# 280543           1                    0              0               0
# 280544           1                    0              0               0
# 280545           1                    0              0               0
#
#         Blattella_germanica  Drosophila_mojavensis  Gryllus_bimaculatus  \
# 0                         4                     97                    0
# 1                       185                      1                    3
# 2                         6                     11                    2
# 3                       950                      0                    5
# 4                        46                      3                    1
# ...                     ...                    ...                  ...
# 280541                    0                      0                    0
# 280542                    0                      0                    0
# 280543                    0                      0                    0
# 280544                    0                      0                    0
# 280545                    0                      0                    0
#
#         Helicoverpa_armigera  Tribolium_castaneum  Bombyx_mori
# 0                         28                    8          290
# 1                          4                   18           81
# 2                          9                   57          101
# 3                         28                    0           96
# 4                         11                    3           80
# ...                      ...                  ...          ...
# 280541                     0                    0            2
# 280542                     0                    0            2
# 280543                     0                    0            2
# 280544                     0                    0            2
# 280545                     0                    0            2
#
# [280546 rows x 10 columns]

# %%
valid_rows = counts_df.apply(lambda row: (row == 1).sum() / len(row) >= 0.75, axis=1)

# %%
print(valid_rows)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 280541    False
# 280542    False
# 280543    False
# 280544    False
# 280545    False
# Length: 280546, dtype: bool

# %%
df_valid = df_filtered[valid_rows]

# %%
print(df_valid)
# Out:
#      Orthogroup                                Acyrthosiphon_pisum  \
# 969   OG0000969  XM_003245443.4, XM_003245444.4, XM_008186260.3...
# 1163  OG0001163                                                NaN
# 1411  OG0001411                     XM_008187848.2, XM_029492190.1
# 1585  OG0001585                                     XM_001952156.4
# 1588  OG0001588                                     XM_008188146.2
# ...         ...                                                ...
# 7895  OG0007895                                     XM_003240088.4
# 7947  OG0007947                                     XM_016806733.2
# 8009  OG0008009                                     NM_001135904.1
# 8033  OG0008033                                     XM_003246949.4
# 8133  OG0008133                                     NM_001145431.1
#
#                         Aedes_aegypti Apis_mellifera  \
# 969                           g599.t1   Amei005982.1
# 1163                        g19837.t1   Amei004124.1
# 1411  g19829.t1, g19829.t2, g19829.t3   Amei000241.1
# 1585                        g10698.t1   Amei007398.1
# 1588                        g24623.t1   Amei004992.1
# ...                               ...            ...
# 7895                              NaN   Amei008252.1
# 7947                              NaN   Amei003065.1
# 8009                              NaN   Amei001429.1
# 8033                              NaN   Amei003453.1
# 8133                        g35414.t1   Amei008956.1
#
#              Blattella_germanica  \
# 969                 Bger013200.1
# 1163                Bger013008.1
# 1411                Bger019557.1
# 1585                Bger013607.1
# 1588                Bger022798.1
# ...                          ...
# 7895  Bger004642.1, Bger025168.1
# 7947                Bger001659.1
# 8009                Bger006224.1
# 8033                         NaN
# 8133                         NaN
#
#                                   Drosophila_mojavensis  \
# 969   XM_032732918.2, XM_032732919.2, XM_032732920.2...
# 1163                                     XM_002008199.4
# 1411                                     XM_002002565.4
# 1585                                     XM_001998534.4
# 1588                                     XM_002006334.4
# ...                                                 ...
# 7895                                     XM_002006118.4
# 7947                                     XM_002004362.4
# 8009                                     XM_032730044.2
# 8033                                     XM_002005242.4
# 8133                                     XM_015162160.3
#
#               Gryllus_bimaculatus                      Helicoverpa_armigera  \
# 969    unassigned_transcript_1435                              Harm007590.1
# 1163  unassigned_transcript_15771                              Harm008361.1
# 1411   unassigned_transcript_9533                              Harm000106.1
# 1585   unassigned_transcript_5224  Harm007793.1, Harm007795.1, Harm010862.1
# 1588   unassigned_transcript_6603                              Harm003650.1
# ...                           ...                                       ...
# 7895   unassigned_transcript_2700                              Harm008718.1
# 7947  unassigned_transcript_16947                              Harm000283.1
# 8009                          NaN                              Harm006863.1
# 8033   unassigned_transcript_2412                              Harm007335.1
# 8133   unassigned_transcript_3850                              Harm007362.1
#
#      Tribolium_castaneum                                        Bombyx_mori
# 969       XM_064358221.1                                     XM_038011403.2
# 1163      XM_015983563.2                                     XM_038013239.2
# 1411         XM_967883.4                                     XM_004925110.5
# 1585      XM_008202231.3     XM_004922106.5, XM_012692664.4, XM_062670893.1
# 1588         XM_965235.5  XM_004922476.5, XM_012695295.4, XM_012695298.4...
# ...                  ...                                                ...
# 7895      XM_008198435.3                                     XM_004930061.5
# 7947         XM_966191.4                                     XM_004928783.5
# 8009      NM_001135906.1                                     NM_001043786.1
# 8033         XM_968869.4                                     XM_004921785.5
# 8133      XM_001808338.4                                     XM_004922782.3
#
# [1982 rows x 10 columns]

# %%
# 输出到文件（同样假设使用制表符分隔，且不保留索引）
df_valid.to_csv('important_species_orthogroups_at_lest_7_species.txt', sep='\t', index=False)
