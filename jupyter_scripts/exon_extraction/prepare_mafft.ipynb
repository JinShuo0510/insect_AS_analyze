# %%
import csv
import os
import re
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord

# %%
# ---------------------------
# 辅助函数：从 FASTA 记录头部解析转录本 ID
# 记录头的格式为: >{transcript_id}_{exon_number}(+/-)
# 这里使用正则表达式匹配“最后一个下划线”前的部分作为 transcript_id
def parse_transcript_id(header):
    # header可能形如 ">XM_004933515.5_1(+)"
    header = header.strip()
    if header.startswith(">"):
        header = header[1:]
    # 利用正则表达式，其中 (?P<transcript>.+) 贪婪匹配直到最后一个下划线，
    # 然后匹配 exon_number 和链号
  #  m = re.match(r"^(?P<transcript>.+)_(?P<exon>\d+)\(([+-])\)$", header)
    m = re.match(r"^(?P<transcript>.+)$", header)

    if m:
        return m.group("transcript")
    else:
        # 如果格式不符合预期，则简单地取第一个下划线前的部分
        return header.split("_")[0]

# %%
# ---------------------------
# 1. 解析同源组表格文件，构建同源组数据结构
orthogroups_file = "90percent_1_1_Lepidoptera_morethan50species_orthogroups.txt"  # 请替换为你的同源组表格文件路径

# 读取表格（假设为 tab 分隔），表头第一列为 Orthogroup，其余列为各物种，列名格式为 {species}.protein
with open(orthogroups_file, "r") as f:
    reader = csv.DictReader(f, delimiter="\t")
    # 获取所有物种列名（去除 Orthogroup 列）
    species_columns = [col for col in reader.fieldnames if col != "Orthogroup"]
    # 将所有行存入列表
    orthogroups = list(reader)

# %%
# ---------------------------
# 2. 对于每个物种，预先加载其外显子 FASTA 文件，建立字典： transcript_id -> list of SeqRecord
# FASTA 文件命名格式为 {species}.exon.fa，其中 species 为列名去掉 ".protein"
species_fasta = {}  # 键：species，值：字典 { transcript_id : [SeqRecord, ...] }
for col in species_columns:
    species = col.replace(".protein", "")
    fasta_file = f"{species}.exon.fasta"
    if not os.path.exists(fasta_file):
        print(f"警告：文件 {fasta_file} 不存在，跳过 {species}！")
        continue

    species_fasta[species] = {}
    # 解析 FASTA 文件中的每条记录
    for record in SeqIO.parse(fasta_file, "fasta"):
        tid = parse_transcript_id(record.description)
        if tid not in species_fasta[species]:
            species_fasta[species][tid] = []
        species_fasta[species][tid].append(record)
    print(f"加载 {fasta_file} 完成，共解析 {len(species_fasta[species])} 个转录本。")
# Out:
# 加载 Bicyclus_anynana.exon.fasta 完成，共解析 1118 个转录本。
# 加载 Bombyx_mori.exon.fasta 完成，共解析 1225 个转录本。
# 加载 Danaus_plexippus.exon.fasta 完成，共解析 1155 个转录本。
# 加载 Heliconius_cydno.exon.fasta 完成，共解析 1287 个转录本。
# 加载 Heliconius_erato.exon.fasta 完成，共解析 1081 个转录本。
# 加载 Heliconius_melpomene.exon.fasta 完成，共解析 1122 个转录本。
# 加载 Helicoverpa_armigera.exon.fasta 完成，共解析 1117 个转录本。
# 加载 Junonia_coenia.exon.fasta 完成，共解析 1191 个转录本。
# 加载 Manduca_sexta.exon.fasta 完成，共解析 1174 个转录本。
# 加载 Ostrinia_furnacalis.exon.fasta 完成，共解析 1124 个转录本。
# 加载 Pieris_napi.exon.fasta 完成，共解析 1140 个转录本。
# 加载 Pieris_rapae.exon.fasta 完成，共解析 1136 个转录本。
# 加载 Plutella_xylostella.exon.fasta 完成，共解析 1137 个转录本。
# 加载 Spodoptera_frugiperda.exon.fasta 完成，共解析 1175 个转录本。
# 加载 Spodoptera_litura.exon.fasta 完成，共解析 1164 个转录本。
# 加载 Vanessa_cardui.exon.fasta 完成，共解析 1116 个转录本。

# %%
# ---------------------------
# 3. 对于每个同源组，提取各物种中对应转录本的所有外显子记录，
# 并在记录的转录本ID前加上物种名称，最后写入文件 {Orthogroup}.fasta
for row in orthogroups:
    orthogroup = row["Orthogroup"]
    records_to_write = []  # 存放所有待写入该同源组的 SeqRecord
    # 遍历各物种的列
    for col in species_columns:
        species = col.replace(".protein", "")
        transcript_ids_field = row[col].strip()
        # 如果该物种没有数据，则跳过
        if transcript_ids_field == "" or transcript_ids_field == "-":
            continue
        # 若单元格中有多个转录本ID，以逗号分隔
        transcript_ids = [tid.strip() for tid in transcript_ids_field.split(",")]
        for tid in transcript_ids:
            if species in species_fasta:
                if tid in species_fasta[species]:
                    # 对每条记录增加物种名称前缀
                    for record in species_fasta[species][tid]:
                        # 构造新的记录，新记录的 header 为 {species}_{原记录header}
                        new_record = SeqRecord(
                            seq=record.seq,
                            id=f"{species}_{record.id}",
                            description=f"{species}_{record.description}"
                        )
                        records_to_write.append(new_record)
                else:
                    print(f"警告：在 {species}.exon.fa 中未找到转录本 {tid}（同源组 {orthogroup}）。")
            else:
                print(f"警告：物种 {species} 的 FASTA 数据未加载。")
    # 写入输出文件，文件命名格式为 {Orthogroup}.fasta
    output_file = f"{orthogroup}.transcript.fasta"
    SeqIO.write(records_to_write, output_file, "fasta")
    print(f"同源组 {orthogroup} 写入 {output_file}，共 {len(records_to_write)} 条记录。")
# Out:
# 同源组 OG0001729 写入 OG0001729.transcript.fasta，共 17 条记录。
# 同源组 OG0002314 写入 OG0002314.transcript.fasta，共 17 条记录。
# 同源组 OG0002514 写入 OG0002514.transcript.fasta，共 17 条记录。
# 同源组 OG0002565 写入 OG0002565.transcript.fasta，共 20 条记录。
# 同源组 OG0002567 写入 OG0002567.transcript.fasta，共 17 条记录。
# 同源组 OG0002614 写入 OG0002614.transcript.fasta，共 18 条记录。
# 同源组 OG0002826 写入 OG0002826.transcript.fasta，共 17 条记录。
# 同源组 OG0002833 写入 OG0002833.transcript.fasta，共 16 条记录。
# 同源组 OG0002883 写入 OG0002883.transcript.fasta，共 17 条记录。
# 同源组 OG0002939 写入 OG0002939.transcript.fasta，共 19 条记录。
# 同源组 OG0003078 写入 OG0003078.transcript.fasta，共 18 条记录。
# 同源组 OG0003182 写入 OG0003182.transcript.fasta，共 17 条记录。
# 同源组 OG0003193 写入 OG0003193.transcript.fasta，共 18 条记录。
# 同源组 OG0003259 写入 OG0003259.transcript.fasta，共 18 条记录。
# 同源组 OG0003438 写入 OG0003438.transcript.fasta，共 15 条记录。
# 同源组 OG0003533 写入 OG0003533.transcript.fasta，共 17 条记录。
# 同源组 OG0003594 写入 OG0003594.transcript.fasta，共 16 条记录。
# 同源组 OG0003599 写入 OG0003599.transcript.fasta，共 15 条记录。
# 同源组 OG0003722 写入 OG0003722.transcript.fasta，共 18 条记录。
# 同源组 OG0003762 写入 OG0003762.transcript.fasta，共 17 条记录。
# 同源组 OG0003800 写入 OG0003800.transcript.fasta，共 19 条记录。
# 同源组 OG0003854 写入 OG0003854.transcript.fasta，共 17 条记录。
# 同源组 OG0003872 写入 OG0003872.transcript.fasta，共 17 条记录。
# 同源组 OG0003915 写入 OG0003915.transcript.fasta，共 17 条记录。
# 同源组 OG0003978 写入 OG0003978.transcript.fasta，共 18 条记录。
# 同源组 OG0003995 写入 OG0003995.transcript.fasta，共 17 条记录。
# 同源组 OG0004117 写入 OG0004117.transcript.fasta，共 17 条记录。
# 同源组 OG0004203 写入 OG0004203.transcript.fasta，共 17 条记录。
# 同源组 OG0004260 写入 OG0004260.transcript.fasta，共 17 条记录。
# 同源组 OG0004269 写入 OG0004269.transcript.fasta，共 16 条记录。
# 同源组 OG0004276 写入 OG0004276.transcript.fasta，共 18 条记录。
# 同源组 OG0004301 写入 OG0004301.transcript.fasta，共 17 条记录。
# 同源组 OG0004306 写入 OG0004306.transcript.fasta，共 17 条记录。
# 同源组 OG0004364 写入 OG0004364.transcript.fasta，共 16 条记录。
# 同源组 OG0004392 写入 OG0004392.transcript.fasta，共 16 条记录。
# 同源组 OG0004451 写入 OG0004451.transcript.fasta，共 18 条记录。
# 同源组 OG0004505 写入 OG0004505.transcript.fasta，共 18 条记录。
# 同源组 OG0004545 写入 OG0004545.transcript.fasta，共 17 条记录。
# 同源组 OG0004560 写入 OG0004560.transcript.fasta，共 17 条记录。
# 同源组 OG0004570 写入 OG0004570.transcript.fasta，共 16 条记录。
# 同源组 OG0004591 写入 OG0004591.transcript.fasta，共 17 条记录。
# 同源组 OG0004620 写入 OG0004620.transcript.fasta，共 17 条记录。
# 同源组 OG0004635 写入 OG0004635.transcript.fasta，共 18 条记录。
# 同源组 OG0004683 写入 OG0004683.transcript.fasta，共 18 条记录。
# 同源组 OG0004689 写入 OG0004689.transcript.fasta，共 17 条记录。
# 同源组 OG0004697 写入 OG0004697.transcript.fasta，共 17 条记录。
# 同源组 OG0004718 写入 OG0004718.transcript.fasta，共 17 条记录。
# 同源组 OG0004748 写入 OG0004748.transcript.fasta，共 18 条记录。
# 同源组 OG0004750 写入 OG0004750.transcript.fasta，共 16 条记录。
# 同源组 OG0004757 写入 OG0004757.transcript.fasta，共 17 条记录。
# 同源组 OG0004766 写入 OG0004766.transcript.fasta，共 17 条记录。
# 同源组 OG0004801 写入 OG0004801.transcript.fasta，共 17 条记录。
# 同源组 OG0004802 写入 OG0004802.transcript.fasta，共 17 条记录。
# 同源组 OG0004816 写入 OG0004816.transcript.fasta，共 17 条记录。
# 同源组 OG0004832 写入 OG0004832.transcript.fasta，共 16 条记录。
# 同源组 OG0004837 写入 OG0004837.transcript.fasta，共 18 条记录。
# 同源组 OG0004859 写入 OG0004859.transcript.fasta，共 19 条记录。
# 同源组 OG0004949 写入 OG0004949.transcript.fasta，共 17 条记录。
# 同源组 OG0004954 写入 OG0004954.transcript.fasta，共 17 条记录。
# 同源组 OG0004965 写入 OG0004965.transcript.fasta，共 16 条记录。
# 同源组 OG0004966 写入 OG0004966.transcript.fasta，共 17 条记录。
# 同源组 OG0004967 写入 OG0004967.transcript.fasta，共 17 条记录。
# 同源组 OG0004974 写入 OG0004974.transcript.fasta，共 17 条记录。
# 同源组 OG0004981 写入 OG0004981.transcript.fasta，共 17 条记录。
# 同源组 OG0004989 写入 OG0004989.transcript.fasta，共 17 条记录。
# 同源组 OG0005025 写入 OG0005025.transcript.fasta，共 17 条记录。
# 同源组 OG0005086 写入 OG0005086.transcript.fasta，共 19 条记录。
# 同源组 OG0005144 写入 OG0005144.transcript.fasta，共 18 条记录。
# 同源组 OG0005181 写入 OG0005181.transcript.fasta，共 17 条记录。
# 同源组 OG0005213 写入 OG0005213.transcript.fasta，共 17 条记录。
# 同源组 OG0005219 写入 OG0005219.transcript.fasta，共 18 条记录。
# 同源组 OG0005258 写入 OG0005258.transcript.fasta，共 17 条记录。
# 同源组 OG0005335 写入 OG0005335.transcript.fasta，共 19 条记录。
# 同源组 OG0005340 写入 OG0005340.transcript.fasta，共 17 条记录。
# 同源组 OG0005343 写入 OG0005343.transcript.fasta，共 19 条记录。
# 同源组 OG0005367 写入 OG0005367.transcript.fasta，共 17 条记录。
# 同源组 OG0005441 写入 OG0005441.transcript.fasta，共 16 条记录。
# 同源组 OG0005445 写入 OG0005445.transcript.fasta，共 17 条记录。
# 同源组 OG0005449 写入 OG0005449.transcript.fasta，共 17 条记录。
# 同源组 OG0005459 写入 OG0005459.transcript.fasta，共 17 条记录。
# 同源组 OG0005500 写入 OG0005500.transcript.fasta，共 19 条记录。
# 同源组 OG0005511 写入 OG0005511.transcript.fasta，共 17 条记录。
# 同源组 OG0005523 写入 OG0005523.transcript.fasta，共 17 条记录。
# 同源组 OG0005579 写入 OG0005579.transcript.fasta，共 16 条记录。
# 同源组 OG0005605 写入 OG0005605.transcript.fasta，共 17 条记录。
# 同源组 OG0005619 写入 OG0005619.transcript.fasta，共 17 条记录。
# 同源组 OG0005622 写入 OG0005622.transcript.fasta，共 18 条记录。
# 同源组 OG0005625 写入 OG0005625.transcript.fasta，共 15 条记录。
# 同源组 OG0005642 写入 OG0005642.transcript.fasta，共 17 条记录。
# 同源组 OG0005723 写入 OG0005723.transcript.fasta，共 17 条记录。
# 同源组 OG0005724 写入 OG0005724.transcript.fasta，共 17 条记录。
# 同源组 OG0005725 写入 OG0005725.transcript.fasta，共 17 条记录。
# 同源组 OG0005749 写入 OG0005749.transcript.fasta，共 18 条记录。
# 同源组 OG0005761 写入 OG0005761.transcript.fasta，共 17 条记录。
# 同源组 OG0005772 写入 OG0005772.transcript.fasta，共 16 条记录。
# 同源组 OG0005781 写入 OG0005781.transcript.fasta，共 17 条记录。
# 同源组 OG0005797 写入 OG0005797.transcript.fasta，共 17 条记录。
# 同源组 OG0005811 写入 OG0005811.transcript.fasta，共 17 条记录。
# 同源组 OG0005832 写入 OG0005832.transcript.fasta，共 17 条记录。
# 同源组 OG0005852 写入 OG0005852.transcript.fasta，共 17 条记录。
# 同源组 OG0005855 写入 OG0005855.transcript.fasta，共 17 条记录。
# 同源组 OG0005857 写入 OG0005857.transcript.fasta，共 17 条记录。
# 同源组 OG0005865 写入 OG0005865.transcript.fasta，共 15 条记录。
# 同源组 OG0005877 写入 OG0005877.transcript.fasta，共 20 条记录。
# 同源组 OG0005879 写入 OG0005879.transcript.fasta，共 17 条记录。
# 同源组 OG0005886 写入 OG0005886.transcript.fasta，共 17 条记录。
# 同源组 OG0005912 写入 OG0005912.transcript.fasta，共 17 条记录。
# 同源组 OG0005913 写入 OG0005913.transcript.fasta，共 16 条记录。
# 同源组 OG0005925 写入 OG0005925.transcript.fasta，共 18 条记录。
# 同源组 OG0005942 写入 OG0005942.transcript.fasta，共 18 条记录。
# 同源组 OG0005945 写入 OG0005945.transcript.fasta，共 17 条记录。
# 同源组 OG0005950 写入 OG0005950.transcript.fasta，共 18 条记录。
# 同源组 OG0005966 写入 OG0005966.transcript.fasta，共 17 条记录。
# 同源组 OG0005973 写入 OG0005973.transcript.fasta，共 18 条记录。
# 同源组 OG0005974 写入 OG0005974.transcript.fasta，共 17 条记录。
# 同源组 OG0005996 写入 OG0005996.transcript.fasta，共 17 条记录。
# 同源组 OG0006023 写入 OG0006023.transcript.fasta，共 17 条记录。
# 同源组 OG0006024 写入 OG0006024.transcript.fasta，共 17 条记录。
# 同源组 OG0006034 写入 OG0006034.transcript.fasta，共 17 条记录。
# 同源组 OG0006035 写入 OG0006035.transcript.fasta，共 15 条记录。
# 同源组 OG0006038 写入 OG0006038.transcript.fasta，共 16 条记录。
# 同源组 OG0006039 写入 OG0006039.transcript.fasta，共 17 条记录。
# 同源组 OG0006041 写入 OG0006041.transcript.fasta，共 16 条记录。
# 同源组 OG0006057 写入 OG0006057.transcript.fasta，共 17 条记录。
# 同源组 OG0006063 写入 OG0006063.transcript.fasta，共 16 条记录。
# 同源组 OG0006067 写入 OG0006067.transcript.fasta，共 17 条记录。
# 同源组 OG0006078 写入 OG0006078.transcript.fasta，共 17 条记录。
# 同源组 OG0006083 写入 OG0006083.transcript.fasta，共 17 条记录。
# 同源组 OG0006086 写入 OG0006086.transcript.fasta，共 17 条记录。
# 同源组 OG0006112 写入 OG0006112.transcript.fasta，共 17 条记录。
# 同源组 OG0006116 写入 OG0006116.transcript.fasta，共 17 条记录。
# 同源组 OG0006160 写入 OG0006160.transcript.fasta，共 17 条记录。
# 同源组 OG0006163 写入 OG0006163.transcript.fasta，共 16 条记录。
# 同源组 OG0006167 写入 OG0006167.transcript.fasta，共 17 条记录。
# 同源组 OG0006168 写入 OG0006168.transcript.fasta，共 17 条记录。
# 同源组 OG0006169 写入 OG0006169.transcript.fasta，共 16 条记录。
# 同源组 OG0006171 写入 OG0006171.transcript.fasta，共 17 条记录。
# 同源组 OG0006175 写入 OG0006175.transcript.fasta，共 17 条记录。
# 同源组 OG0006178 写入 OG0006178.transcript.fasta，共 17 条记录。
# 同源组 OG0006186 写入 OG0006186.transcript.fasta，共 17 条记录。
# 同源组 OG0006190 写入 OG0006190.transcript.fasta，共 17 条记录。
# 同源组 OG0006192 写入 OG0006192.transcript.fasta，共 16 条记录。
# 同源组 OG0006194 写入 OG0006194.transcript.fasta，共 17 条记录。
# 同源组 OG0006210 写入 OG0006210.transcript.fasta，共 18 条记录。
# 同源组 OG0006213 写入 OG0006213.transcript.fasta，共 17 条记录。
# 同源组 OG0006216 写入 OG0006216.transcript.fasta，共 16 条记录。
# 同源组 OG0006217 写入 OG0006217.transcript.fasta，共 16 条记录。
# 同源组 OG0006220 写入 OG0006220.transcript.fasta，共 16 条记录。
# 同源组 OG0006241 写入 OG0006241.transcript.fasta，共 17 条记录。
# 同源组 OG0006243 写入 OG0006243.transcript.fasta，共 17 条记录。
# 同源组 OG0006322 写入 OG0006322.transcript.fasta，共 17 条记录。
# 同源组 OG0006343 写入 OG0006343.transcript.fasta，共 17 条记录。
# 同源组 OG0006347 写入 OG0006347.transcript.fasta，共 17 条记录。
# 同源组 OG0006348 写入 OG0006348.transcript.fasta，共 17 条记录。
# 同源组 OG0006349 写入 OG0006349.transcript.fasta，共 18 条记录。
# 同源组 OG0006359 写入 OG0006359.transcript.fasta，共 17 条记录。
# 同源组 OG0006363 写入 OG0006363.transcript.fasta，共 17 条记录。
# 同源组 OG0006372 写入 OG0006372.transcript.fasta，共 16 条记录。
# 同源组 OG0006379 写入 OG0006379.transcript.fasta，共 17 条记录。
# 同源组 OG0006380 写入 OG0006380.transcript.fasta，共 16 条记录。
# 同源组 OG0006391 写入 OG0006391.transcript.fasta，共 17 条记录。
# 同源组 OG0006394 写入 OG0006394.transcript.fasta，共 17 条记录。
# 同源组 OG0006395 写入 OG0006395.transcript.fasta，共 16 条记录。
# 同源组 OG0006397 写入 OG0006397.transcript.fasta，共 17 条记录。
# 同源组 OG0006410 写入 OG0006410.transcript.fasta，共 17 条记录。
# 同源组 OG0006412 写入 OG0006412.transcript.fasta，共 17 条记录。
# 同源组 OG0006426 写入 OG0006426.transcript.fasta，共 16 条记录。
# 同源组 OG0006434 写入 OG0006434.transcript.fasta，共 17 条记录。
# 同源组 OG0006444 写入 OG0006444.transcript.fasta，共 17 条记录。
# 同源组 OG0006453 写入 OG0006453.transcript.fasta，共 16 条记录。
# 同源组 OG0006469 写入 OG0006469.transcript.fasta，共 17 条记录。
# 同源组 OG0006501 写入 OG0006501.transcript.fasta，共 16 条记录。
# 同源组 OG0006507 写入 OG0006507.transcript.fasta，共 18 条记录。
# 同源组 OG0006508 写入 OG0006508.transcript.fasta，共 17 条记录。
# 同源组 OG0006510 写入 OG0006510.transcript.fasta，共 17 条记录。
# 同源组 OG0006519 写入 OG0006519.transcript.fasta，共 19 条记录。
# 同源组 OG0006526 写入 OG0006526.transcript.fasta，共 16 条记录。
# 同源组 OG0006532 写入 OG0006532.transcript.fasta，共 19 条记录。
# 同源组 OG0006536 写入 OG0006536.transcript.fasta，共 17 条记录。
# 同源组 OG0006538 写入 OG0006538.transcript.fasta，共 17 条记录。
# 同源组 OG0006543 写入 OG0006543.transcript.fasta，共 17 条记录。
# 同源组 OG0006544 写入 OG0006544.transcript.fasta，共 16 条记录。
# 同源组 OG0006548 写入 OG0006548.transcript.fasta，共 17 条记录。
# 同源组 OG0006552 写入 OG0006552.transcript.fasta，共 17 条记录。
# 同源组 OG0006553 写入 OG0006553.transcript.fasta，共 17 条记录。
# 同源组 OG0006557 写入 OG0006557.transcript.fasta，共 16 条记录。
# 同源组 OG0006559 写入 OG0006559.transcript.fasta，共 17 条记录。
# 同源组 OG0006562 写入 OG0006562.transcript.fasta，共 18 条记录。
# 同源组 OG0006564 写入 OG0006564.transcript.fasta，共 18 条记录。
# 同源组 OG0006573 写入 OG0006573.transcript.fasta，共 16 条记录。
# 同源组 OG0006577 写入 OG0006577.transcript.fasta，共 18 条记录。
# 同源组 OG0006579 写入 OG0006579.transcript.fasta，共 17 条记录。
# 同源组 OG0006582 写入 OG0006582.transcript.fasta，共 16 条记录。
# 同源组 OG0006595 写入 OG0006595.transcript.fasta，共 16 条记录。
# 同源组 OG0006601 写入 OG0006601.transcript.fasta，共 17 条记录。
# 同源组 OG0006605 写入 OG0006605.transcript.fasta，共 16 条记录。
# 同源组 OG0006612 写入 OG0006612.transcript.fasta，共 17 条记录。
# 同源组 OG0006628 写入 OG0006628.transcript.fasta，共 17 条记录。
# 同源组 OG0006647 写入 OG0006647.transcript.fasta，共 17 条记录。
# 同源组 OG0006652 写入 OG0006652.transcript.fasta，共 19 条记录。
# 同源组 OG0006672 写入 OG0006672.transcript.fasta，共 17 条记录。
# 同源组 OG0006674 写入 OG0006674.transcript.fasta，共 17 条记录。
# 同源组 OG0006675 写入 OG0006675.transcript.fasta，共 17 条记录。
# 同源组 OG0006683 写入 OG0006683.transcript.fasta，共 18 条记录。
# 同源组 OG0006684 写入 OG0006684.transcript.fasta，共 16 条记录。
# 同源组 OG0006686 写入 OG0006686.transcript.fasta，共 17 条记录。
# 同源组 OG0006688 写入 OG0006688.transcript.fasta，共 17 条记录。
# 同源组 OG0006691 写入 OG0006691.transcript.fasta，共 16 条记录。
# 同源组 OG0006701 写入 OG0006701.transcript.fasta，共 17 条记录。
# 同源组 OG0006706 写入 OG0006706.transcript.fasta，共 16 条记录。
# 同源组 OG0006707 写入 OG0006707.transcript.fasta，共 16 条记录。
# 同源组 OG0006710 写入 OG0006710.transcript.fasta，共 17 条记录。
# 同源组 OG0006711 写入 OG0006711.transcript.fasta，共 17 条记录。
# 同源组 OG0006738 写入 OG0006738.transcript.fasta，共 17 条记录。
# 同源组 OG0006739 写入 OG0006739.transcript.fasta，共 17 条记录。
# 同源组 OG0006741 写入 OG0006741.transcript.fasta，共 17 条记录。
# 同源组 OG0006745 写入 OG0006745.transcript.fasta，共 17 条记录。
# 同源组 OG0006754 写入 OG0006754.transcript.fasta，共 16 条记录。
# 同源组 OG0006766 写入 OG0006766.transcript.fasta，共 16 条记录。
# 同源组 OG0006768 写入 OG0006768.transcript.fasta，共 17 条记录。
# 同源组 OG0006776 写入 OG0006776.transcript.fasta，共 17 条记录。
# 同源组 OG0006777 写入 OG0006777.transcript.fasta，共 23 条记录。
# 同源组 OG0006780 写入 OG0006780.transcript.fasta，共 15 条记录。
# 同源组 OG0006784 写入 OG0006784.transcript.fasta，共 17 条记录。
# 同源组 OG0006806 写入 OG0006806.transcript.fasta，共 17 条记录。
# 同源组 OG0006820 写入 OG0006820.transcript.fasta，共 16 条记录。
# 同源组 OG0006829 写入 OG0006829.transcript.fasta，共 17 条记录。
# 同源组 OG0006834 写入 OG0006834.transcript.fasta，共 17 条记录。
# 同源组 OG0006849 写入 OG0006849.transcript.fasta，共 17 条记录。
# 同源组 OG0006862 写入 OG0006862.transcript.fasta，共 15 条记录。
# 同源组 OG0006864 写入 OG0006864.transcript.fasta，共 17 条记录。
# 同源组 OG0006867 写入 OG0006867.transcript.fasta，共 17 条记录。
# 同源组 OG0006868 写入 OG0006868.transcript.fasta，共 16 条记录。
# 同源组 OG0006873 写入 OG0006873.transcript.fasta，共 17 条记录。
# 同源组 OG0006882 写入 OG0006882.transcript.fasta，共 16 条记录。
# 同源组 OG0006890 写入 OG0006890.transcript.fasta，共 17 条记录。
# 同源组 OG0006895 写入 OG0006895.transcript.fasta，共 15 条记录。
# 同源组 OG0006905 写入 OG0006905.transcript.fasta，共 16 条记录。
# 同源组 OG0006909 写入 OG0006909.transcript.fasta，共 18 条记录。
# 同源组 OG0006912 写入 OG0006912.transcript.fasta，共 16 条记录。
# 同源组 OG0006918 写入 OG0006918.transcript.fasta，共 17 条记录。
# 同源组 OG0006927 写入 OG0006927.transcript.fasta，共 15 条记录。
# 同源组 OG0006928 写入 OG0006928.transcript.fasta，共 17 条记录。
# 同源组 OG0006931 写入 OG0006931.transcript.fasta，共 17 条记录。
# 同源组 OG0006933 写入 OG0006933.transcript.fasta，共 16 条记录。
# 同源组 OG0006934 写入 OG0006934.transcript.fasta，共 16 条记录。
# 同源组 OG0006937 写入 OG0006937.transcript.fasta，共 18 条记录。
# 同源组 OG0006939 写入 OG0006939.transcript.fasta，共 17 条记录。
# 同源组 OG0006940 写入 OG0006940.transcript.fasta，共 17 条记录。
# 同源组 OG0006943 写入 OG0006943.transcript.fasta，共 16 条记录。
# 同源组 OG0006957 写入 OG0006957.transcript.fasta，共 17 条记录。
# 同源组 OG0006960 写入 OG0006960.transcript.fasta，共 17 条记录。
# 同源组 OG0006966 写入 OG0006966.transcript.fasta，共 16 条记录。
# 同源组 OG0006977 写入 OG0006977.transcript.fasta，共 17 条记录。
# 同源组 OG0006986 写入 OG0006986.transcript.fasta，共 17 条记录。
# 同源组 OG0007023 写入 OG0007023.transcript.fasta，共 18 条记录。
# 同源组 OG0007026 写入 OG0007026.transcript.fasta，共 16 条记录。
# 同源组 OG0007053 写入 OG0007053.transcript.fasta，共 17 条记录。
# 同源组 OG0007065 写入 OG0007065.transcript.fasta，共 19 条记录。
# 同源组 OG0007066 写入 OG0007066.transcript.fasta，共 22 条记录。
# 同源组 OG0007070 写入 OG0007070.transcript.fasta，共 16 条记录。
# 同源组 OG0007076 写入 OG0007076.transcript.fasta，共 16 条记录。
# 同源组 OG0007080 写入 OG0007080.transcript.fasta，共 17 条记录。
# 同源组 OG0007095 写入 OG0007095.transcript.fasta，共 17 条记录。
# 同源组 OG0007096 写入 OG0007096.transcript.fasta，共 17 条记录。
# 同源组 OG0007098 写入 OG0007098.transcript.fasta，共 16 条记录。
# 同源组 OG0007099 写入 OG0007099.transcript.fasta，共 17 条记录。
# 同源组 OG0007100 写入 OG0007100.transcript.fasta，共 16 条记录。
# 同源组 OG0007101 写入 OG0007101.transcript.fasta，共 15 条记录。
# 同源组 OG0007112 写入 OG0007112.transcript.fasta，共 16 条记录。
# 同源组 OG0007114 写入 OG0007114.transcript.fasta，共 16 条记录。
# 同源组 OG0007119 写入 OG0007119.transcript.fasta，共 17 条记录。
# 同源组 OG0007120 写入 OG0007120.transcript.fasta，共 18 条记录。
# 同源组 OG0007125 写入 OG0007125.transcript.fasta，共 17 条记录。
# 同源组 OG0007134 写入 OG0007134.transcript.fasta，共 22 条记录。
# 同源组 OG0007144 写入 OG0007144.transcript.fasta，共 17 条记录。
# 同源组 OG0007146 写入 OG0007146.transcript.fasta，共 15 条记录。
# 同源组 OG0007152 写入 OG0007152.transcript.fasta，共 17 条记录。
# 同源组 OG0007156 写入 OG0007156.transcript.fasta，共 17 条记录。
# 同源组 OG0007157 写入 OG0007157.transcript.fasta，共 17 条记录。
# 同源组 OG0007158 写入 OG0007158.transcript.fasta，共 17 条记录。
# 同源组 OG0007160 写入 OG0007160.transcript.fasta，共 16 条记录。
# 同源组 OG0007169 写入 OG0007169.transcript.fasta，共 17 条记录。
# 同源组 OG0007174 写入 OG0007174.transcript.fasta，共 17 条记录。
# 同源组 OG0007177 写入 OG0007177.transcript.fasta，共 17 条记录。
# 同源组 OG0007179 写入 OG0007179.transcript.fasta，共 17 条记录。
# 同源组 OG0007184 写入 OG0007184.transcript.fasta，共 15 条记录。
# 同源组 OG0007195 写入 OG0007195.transcript.fasta，共 17 条记录。
# 同源组 OG0007202 写入 OG0007202.transcript.fasta，共 17 条记录。
# 同源组 OG0007205 写入 OG0007205.transcript.fasta，共 17 条记录。
# 同源组 OG0007208 写入 OG0007208.transcript.fasta，共 17 条记录。
# 同源组 OG0007211 写入 OG0007211.transcript.fasta，共 17 条记录。
# 同源组 OG0007221 写入 OG0007221.transcript.fasta，共 17 条记录。
# 同源组 OG0007230 写入 OG0007230.transcript.fasta，共 17 条记录。
# 同源组 OG0007235 写入 OG0007235.transcript.fasta，共 15 条记录。
# 同源组 OG0007241 写入 OG0007241.transcript.fasta，共 17 条记录。
# 同源组 OG0007248 写入 OG0007248.transcript.fasta，共 18 条记录。
# 同源组 OG0007273 写入 OG0007273.transcript.fasta，共 17 条记录。
# 同源组 OG0007274 写入 OG0007274.transcript.fasta，共 16 条记录。
# 同源组 OG0007276 写入 OG0007276.transcript.fasta，共 16 条记录。
# 同源组 OG0007279 写入 OG0007279.transcript.fasta，共 16 条记录。
# 同源组 OG0007283 写入 OG0007283.transcript.fasta，共 17 条记录。
# 同源组 OG0007286 写入 OG0007286.transcript.fasta，共 17 条记录。
# 同源组 OG0007288 写入 OG0007288.transcript.fasta，共 17 条记录。
# 同源组 OG0007291 写入 OG0007291.transcript.fasta，共 16 条记录。
# 同源组 OG0007293 写入 OG0007293.transcript.fasta，共 16 条记录。
# 同源组 OG0007297 写入 OG0007297.transcript.fasta，共 17 条记录。
# 同源组 OG0007298 写入 OG0007298.transcript.fasta，共 16 条记录。
# 同源组 OG0007299 写入 OG0007299.transcript.fasta，共 16 条记录。
# 同源组 OG0007301 写入 OG0007301.transcript.fasta，共 17 条记录。
# 同源组 OG0007303 写入 OG0007303.transcript.fasta，共 18 条记录。
# 同源组 OG0007305 写入 OG0007305.transcript.fasta，共 17 条记录。
# 同源组 OG0007307 写入 OG0007307.transcript.fasta，共 17 条记录。
# 同源组 OG0007308 写入 OG0007308.transcript.fasta，共 17 条记录。
# 同源组 OG0007310 写入 OG0007310.transcript.fasta，共 18 条记录。
# 同源组 OG0007312 写入 OG0007312.transcript.fasta，共 17 条记录。
# 同源组 OG0007313 写入 OG0007313.transcript.fasta，共 17 条记录。
# 同源组 OG0007317 写入 OG0007317.transcript.fasta，共 17 条记录。
# 同源组 OG0007320 写入 OG0007320.transcript.fasta，共 18 条记录。
# 同源组 OG0007331 写入 OG0007331.transcript.fasta，共 17 条记录。
# 同源组 OG0007332 写入 OG0007332.transcript.fasta，共 17 条记录。
# 同源组 OG0007333 写入 OG0007333.transcript.fasta，共 15 条记录。
# 同源组 OG0007338 写入 OG0007338.transcript.fasta，共 16 条记录。
# 同源组 OG0007340 写入 OG0007340.transcript.fasta，共 17 条记录。
# 同源组 OG0007341 写入 OG0007341.transcript.fasta，共 17 条记录。
# 同源组 OG0007342 写入 OG0007342.transcript.fasta，共 16 条记录。
# 同源组 OG0007343 写入 OG0007343.transcript.fasta，共 17 条记录。
# 同源组 OG0007350 写入 OG0007350.transcript.fasta，共 17 条记录。
# 同源组 OG0007351 写入 OG0007351.transcript.fasta，共 17 条记录。
# 同源组 OG0007361 写入 OG0007361.transcript.fasta，共 17 条记录。
# 同源组 OG0007364 写入 OG0007364.transcript.fasta，共 15 条记录。
# 同源组 OG0007365 写入 OG0007365.transcript.fasta，共 16 条记录。
# 同源组 OG0007366 写入 OG0007366.transcript.fasta，共 17 条记录。
# 同源组 OG0007371 写入 OG0007371.transcript.fasta，共 17 条记录。
# 同源组 OG0007373 写入 OG0007373.transcript.fasta，共 17 条记录。
# 同源组 OG0007379 写入 OG0007379.transcript.fasta，共 17 条记录。
# 同源组 OG0007388 写入 OG0007388.transcript.fasta，共 17 条记录。
# 同源组 OG0007390 写入 OG0007390.transcript.fasta，共 16 条记录。
# 同源组 OG0007391 写入 OG0007391.transcript.fasta，共 18 条记录。
# 同源组 OG0007415 写入 OG0007415.transcript.fasta，共 17 条记录。
# 同源组 OG0007430 写入 OG0007430.transcript.fasta，共 18 条记录。
# 同源组 OG0007436 写入 OG0007436.transcript.fasta，共 17 条记录。
# 同源组 OG0007452 写入 OG0007452.transcript.fasta，共 17 条记录。
# 同源组 OG0007457 写入 OG0007457.transcript.fasta，共 17 条记录。
# 同源组 OG0007459 写入 OG0007459.transcript.fasta，共 16 条记录。
# 同源组 OG0007469 写入 OG0007469.transcript.fasta，共 16 条记录。
# 同源组 OG0007481 写入 OG0007481.transcript.fasta，共 15 条记录。
# 同源组 OG0007482 写入 OG0007482.transcript.fasta，共 17 条记录。
# 同源组 OG0007487 写入 OG0007487.transcript.fasta，共 20 条记录。
# 同源组 OG0007489 写入 OG0007489.transcript.fasta，共 17 条记录。
# 同源组 OG0007490 写入 OG0007490.transcript.fasta，共 17 条记录。
# 同源组 OG0007492 写入 OG0007492.transcript.fasta，共 17 条记录。
# 同源组 OG0007493 写入 OG0007493.transcript.fasta，共 17 条记录。
# 同源组 OG0007494 写入 OG0007494.transcript.fasta，共 17 条记录。
# 同源组 OG0007500 写入 OG0007500.transcript.fasta，共 17 条记录。
# 同源组 OG0007502 写入 OG0007502.transcript.fasta，共 17 条记录。
# 同源组 OG0007506 写入 OG0007506.transcript.fasta，共 16 条记录。
# 同源组 OG0007508 写入 OG0007508.transcript.fasta，共 16 条记录。
# 同源组 OG0007514 写入 OG0007514.transcript.fasta，共 16 条记录。
# 同源组 OG0007515 写入 OG0007515.transcript.fasta，共 17 条记录。
# 同源组 OG0007516 写入 OG0007516.transcript.fasta，共 17 条记录。
# 同源组 OG0007522 写入 OG0007522.transcript.fasta，共 17 条记录。
# 同源组 OG0007524 写入 OG0007524.transcript.fasta，共 16 条记录。
# 同源组 OG0007528 写入 OG0007528.transcript.fasta，共 17 条记录。
# 同源组 OG0007530 写入 OG0007530.transcript.fasta，共 16 条记录。
# 同源组 OG0007531 写入 OG0007531.transcript.fasta，共 15 条记录。
# 同源组 OG0007535 写入 OG0007535.transcript.fasta，共 17 条记录。
# 同源组 OG0007542 写入 OG0007542.transcript.fasta，共 18 条记录。
# 同源组 OG0007543 写入 OG0007543.transcript.fasta，共 15 条记录。
# 同源组 OG0007544 写入 OG0007544.transcript.fasta，共 17 条记录。
# 同源组 OG0007546 写入 OG0007546.transcript.fasta，共 17 条记录。
# 同源组 OG0007548 写入 OG0007548.transcript.fasta，共 17 条记录。
# 同源组 OG0007551 写入 OG0007551.transcript.fasta，共 17 条记录。
# 同源组 OG0007555 写入 OG0007555.transcript.fasta，共 15 条记录。
# 同源组 OG0007558 写入 OG0007558.transcript.fasta，共 17 条记录。
# 同源组 OG0007559 写入 OG0007559.transcript.fasta，共 17 条记录。
# 同源组 OG0007560 写入 OG0007560.transcript.fasta，共 17 条记录。
# 同源组 OG0007563 写入 OG0007563.transcript.fasta，共 17 条记录。
# 同源组 OG0007566 写入 OG0007566.transcript.fasta，共 17 条记录。
# 同源组 OG0007567 写入 OG0007567.transcript.fasta，共 16 条记录。
# 同源组 OG0007575 写入 OG0007575.transcript.fasta，共 17 条记录。
# 同源组 OG0007581 写入 OG0007581.transcript.fasta，共 17 条记录。
# 同源组 OG0007592 写入 OG0007592.transcript.fasta，共 17 条记录。
# 同源组 OG0007618 写入 OG0007618.transcript.fasta，共 17 条记录。
# 同源组 OG0007621 写入 OG0007621.transcript.fasta，共 17 条记录。
# 同源组 OG0007622 写入 OG0007622.transcript.fasta，共 17 条记录。
# 同源组 OG0007624 写入 OG0007624.transcript.fasta，共 17 条记录。
# 同源组 OG0007645 写入 OG0007645.transcript.fasta，共 17 条记录。
# 同源组 OG0007650 写入 OG0007650.transcript.fasta，共 16 条记录。
# 同源组 OG0007663 写入 OG0007663.transcript.fasta，共 17 条记录。
# 同源组 OG0007665 写入 OG0007665.transcript.fasta，共 17 条记录。
# 同源组 OG0007666 写入 OG0007666.transcript.fasta，共 16 条记录。
# 同源组 OG0007669 写入 OG0007669.transcript.fasta，共 17 条记录。
# 同源组 OG0007690 写入 OG0007690.transcript.fasta，共 16 条记录。
# 同源组 OG0007693 写入 OG0007693.transcript.fasta，共 17 条记录。
# 同源组 OG0007699 写入 OG0007699.transcript.fasta，共 17 条记录。
# 同源组 OG0007700 写入 OG0007700.transcript.fasta，共 17 条记录。
# 同源组 OG0007702 写入 OG0007702.transcript.fasta，共 17 条记录。
# 同源组 OG0007705 写入 OG0007705.transcript.fasta，共 16 条记录。
# 同源组 OG0007706 写入 OG0007706.transcript.fasta，共 17 条记录。
# 同源组 OG0007707 写入 OG0007707.transcript.fasta，共 17 条记录。
# 同源组 OG0007713 写入 OG0007713.transcript.fasta，共 17 条记录。
# 同源组 OG0007715 写入 OG0007715.transcript.fasta，共 17 条记录。
# 同源组 OG0007719 写入 OG0007719.transcript.fasta，共 17 条记录。
# 同源组 OG0007720 写入 OG0007720.transcript.fasta，共 16 条记录。
# 同源组 OG0007722 写入 OG0007722.transcript.fasta，共 17 条记录。
# 同源组 OG0007723 写入 OG0007723.transcript.fasta，共 19 条记录。
# 同源组 OG0007724 写入 OG0007724.transcript.fasta，共 17 条记录。
# 同源组 OG0007730 写入 OG0007730.transcript.fasta，共 17 条记录。
# 同源组 OG0007732 写入 OG0007732.transcript.fasta，共 16 条记录。
# 同源组 OG0007739 写入 OG0007739.transcript.fasta，共 16 条记录。
# 同源组 OG0007741 写入 OG0007741.transcript.fasta，共 15 条记录。
# 同源组 OG0007743 写入 OG0007743.transcript.fasta，共 17 条记录。
# 同源组 OG0007744 写入 OG0007744.transcript.fasta，共 17 条记录。
# 同源组 OG0007748 写入 OG0007748.transcript.fasta，共 17 条记录。
# 同源组 OG0007749 写入 OG0007749.transcript.fasta，共 15 条记录。
# 同源组 OG0007752 写入 OG0007752.transcript.fasta，共 16 条记录。
# 同源组 OG0007757 写入 OG0007757.transcript.fasta，共 18 条记录。
# 同源组 OG0007758 写入 OG0007758.transcript.fasta，共 16 条记录。
# 同源组 OG0007762 写入 OG0007762.transcript.fasta，共 18 条记录。
# 同源组 OG0007764 写入 OG0007764.transcript.fasta，共 17 条记录。
# 同源组 OG0007767 写入 OG0007767.transcript.fasta，共 17 条记录。
# 同源组 OG0007768 写入 OG0007768.transcript.fasta，共 16 条记录。
# 同源组 OG0007769 写入 OG0007769.transcript.fasta，共 17 条记录。
# 同源组 OG0007770 写入 OG0007770.transcript.fasta，共 17 条记录。
# 同源组 OG0007775 写入 OG0007775.transcript.fasta，共 16 条记录。
# 同源组 OG0007776 写入 OG0007776.transcript.fasta，共 19 条记录。
# 同源组 OG0007777 写入 OG0007777.transcript.fasta，共 16 条记录。
# 同源组 OG0007780 写入 OG0007780.transcript.fasta，共 16 条记录。
# 同源组 OG0007782 写入 OG0007782.transcript.fasta，共 16 条记录。
# 同源组 OG0007785 写入 OG0007785.transcript.fasta，共 17 条记录。
# 同源组 OG0007790 写入 OG0007790.transcript.fasta，共 17 条记录。
# 同源组 OG0007793 写入 OG0007793.transcript.fasta，共 17 条记录。
# 同源组 OG0007795 写入 OG0007795.transcript.fasta，共 16 条记录。
# 同源组 OG0007799 写入 OG0007799.transcript.fasta，共 16 条记录。
# 同源组 OG0007808 写入 OG0007808.transcript.fasta，共 17 条记录。
# 同源组 OG0007817 写入 OG0007817.transcript.fasta，共 17 条记录。
# 同源组 OG0007821 写入 OG0007821.transcript.fasta，共 17 条记录。
# 同源组 OG0007830 写入 OG0007830.transcript.fasta，共 17 条记录。
# 同源组 OG0007833 写入 OG0007833.transcript.fasta，共 17 条记录。
# 同源组 OG0007834 写入 OG0007834.transcript.fasta，共 16 条记录。
# 同源组 OG0007836 写入 OG0007836.transcript.fasta，共 18 条记录。
# 同源组 OG0007851 写入 OG0007851.transcript.fasta，共 17 条记录。
# 同源组 OG0007856 写入 OG0007856.transcript.fasta，共 17 条记录。
# 同源组 OG0007858 写入 OG0007858.transcript.fasta，共 17 条记录。
# 同源组 OG0007865 写入 OG0007865.transcript.fasta，共 17 条记录。
# 同源组 OG0007866 写入 OG0007866.transcript.fasta，共 15 条记录。
# 同源组 OG0007868 写入 OG0007868.transcript.fasta，共 17 条记录。
# 同源组 OG0007870 写入 OG0007870.transcript.fasta，共 18 条记录。
# 同源组 OG0007878 写入 OG0007878.transcript.fasta，共 16 条记录。
# 同源组 OG0007885 写入 OG0007885.transcript.fasta，共 17 条记录。
# 同源组 OG0007898 写入 OG0007898.transcript.fasta，共 17 条记录。
# 同源组 OG0007901 写入 OG0007901.transcript.fasta，共 16 条记录。
# 同源组 OG0007902 写入 OG0007902.transcript.fasta，共 16 条记录。
# 同源组 OG0007904 写入 OG0007904.transcript.fasta，共 16 条记录。
# 同源组 OG0007906 写入 OG0007906.transcript.fasta，共 16 条记录。
# 同源组 OG0007910 写入 OG0007910.transcript.fasta，共 16 条记录。
# 同源组 OG0007912 写入 OG0007912.transcript.fasta，共 18 条记录。
# 同源组 OG0007914 写入 OG0007914.transcript.fasta，共 15 条记录。
# 同源组 OG0007916 写入 OG0007916.transcript.fasta，共 16 条记录。
# 同源组 OG0007918 写入 OG0007918.transcript.fasta，共 16 条记录。
# 同源组 OG0007921 写入 OG0007921.transcript.fasta，共 17 条记录。
# 同源组 OG0007924 写入 OG0007924.transcript.fasta，共 16 条记录。
# 同源组 OG0007929 写入 OG0007929.transcript.fasta，共 17 条记录。
# 同源组 OG0007930 写入 OG0007930.transcript.fasta，共 17 条记录。
# 同源组 OG0007931 写入 OG0007931.transcript.fasta，共 16 条记录。
# 同源组 OG0007935 写入 OG0007935.transcript.fasta，共 18 条记录。
# 同源组 OG0007937 写入 OG0007937.transcript.fasta，共 16 条记录。
# 同源组 OG0007939 写入 OG0007939.transcript.fasta，共 16 条记录。
# 同源组 OG0007940 写入 OG0007940.transcript.fasta，共 17 条记录。
# 同源组 OG0007945 写入 OG0007945.transcript.fasta，共 18 条记录。
# 同源组 OG0007946 写入 OG0007946.transcript.fasta，共 17 条记录。
# 同源组 OG0007947 写入 OG0007947.transcript.fasta，共 17 条记录。
# 同源组 OG0007949 写入 OG0007949.transcript.fasta，共 15 条记录。
# 同源组 OG0007955 写入 OG0007955.transcript.fasta，共 17 条记录。
# 同源组 OG0007957 写入 OG0007957.transcript.fasta，共 15 条记录。
# 同源组 OG0007960 写入 OG0007960.transcript.fasta，共 16 条记录。
# 同源组 OG0007964 写入 OG0007964.transcript.fasta，共 16 条记录。
# 同源组 OG0007977 写入 OG0007977.transcript.fasta，共 15 条记录。
# 同源组 OG0007980 写入 OG0007980.transcript.fasta，共 16 条记录。
# 同源组 OG0007984 写入 OG0007984.transcript.fasta，共 21 条记录。
# 同源组 OG0007986 写入 OG0007986.transcript.fasta，共 17 条记录。
# 同源组 OG0007989 写入 OG0007989.transcript.fasta，共 16 条记录。
# 同源组 OG0007991 写入 OG0007991.transcript.fasta，共 17 条记录。
# 同源组 OG0007993 写入 OG0007993.transcript.fasta，共 17 条记录。
# 同源组 OG0007994 写入 OG0007994.transcript.fasta，共 17 条记录。
# 同源组 OG0007998 写入 OG0007998.transcript.fasta，共 18 条记录。
# 同源组 OG0008006 写入 OG0008006.transcript.fasta，共 17 条记录。
# 同源组 OG0008008 写入 OG0008008.transcript.fasta，共 16 条记录。
# 同源组 OG0008011 写入 OG0008011.transcript.fasta，共 17 条记录。
# 同源组 OG0008014 写入 OG0008014.transcript.fasta，共 17 条记录。
# 同源组 OG0008017 写入 OG0008017.transcript.fasta，共 17 条记录。
# 同源组 OG0008021 写入 OG0008021.transcript.fasta，共 16 条记录。
# 同源组 OG0008030 写入 OG0008030.transcript.fasta，共 19 条记录。
# 同源组 OG0008031 写入 OG0008031.transcript.fasta，共 15 条记录。
# 同源组 OG0008046 写入 OG0008046.transcript.fasta，共 17 条记录。
# 同源组 OG0008048 写入 OG0008048.transcript.fasta，共 17 条记录。
# 同源组 OG0008056 写入 OG0008056.transcript.fasta，共 17 条记录。
# 同源组 OG0008057 写入 OG0008057.transcript.fasta，共 17 条记录。
# 同源组 OG0008059 写入 OG0008059.transcript.fasta，共 17 条记录。
# 同源组 OG0008060 写入 OG0008060.transcript.fasta，共 18 条记录。
# 同源组 OG0008063 写入 OG0008063.transcript.fasta，共 16 条记录。
# 同源组 OG0008081 写入 OG0008081.transcript.fasta，共 16 条记录。
# 同源组 OG0008086 写入 OG0008086.transcript.fasta，共 15 条记录。
# 同源组 OG0008091 写入 OG0008091.transcript.fasta，共 18 条记录。
# 同源组 OG0008118 写入 OG0008118.transcript.fasta，共 16 条记录。
# 同源组 OG0008120 写入 OG0008120.transcript.fasta，共 15 条记录。
# 同源组 OG0008123 写入 OG0008123.transcript.fasta，共 17 条记录。
# 同源组 OG0008124 写入 OG0008124.transcript.fasta，共 17 条记录。
# 同源组 OG0008134 写入 OG0008134.transcript.fasta，共 17 条记录。
# 同源组 OG0008141 写入 OG0008141.transcript.fasta，共 17 条记录。
# 同源组 OG0008142 写入 OG0008142.transcript.fasta，共 17 条记录。
# 同源组 OG0008144 写入 OG0008144.transcript.fasta，共 17 条记录。
# 同源组 OG0008146 写入 OG0008146.transcript.fasta，共 16 条记录。
# 同源组 OG0008148 写入 OG0008148.transcript.fasta，共 16 条记录。
# 同源组 OG0008149 写入 OG0008149.transcript.fasta，共 15 条记录。
# 同源组 OG0008150 写入 OG0008150.transcript.fasta，共 16 条记录。
# 同源组 OG0008151 写入 OG0008151.transcript.fasta，共 18 条记录。
# 同源组 OG0008153 写入 OG0008153.transcript.fasta，共 18 条记录。
# 同源组 OG0008157 写入 OG0008157.transcript.fasta，共 17 条记录。
# 同源组 OG0008158 写入 OG0008158.transcript.fasta，共 17 条记录。
# 同源组 OG0008167 写入 OG0008167.transcript.fasta，共 16 条记录。
# 同源组 OG0008168 写入 OG0008168.transcript.fasta，共 17 条记录。
# 同源组 OG0008170 写入 OG0008170.transcript.fasta，共 15 条记录。
# 同源组 OG0008174 写入 OG0008174.transcript.fasta，共 16 条记录。
# 同源组 OG0008175 写入 OG0008175.transcript.fasta，共 15 条记录。
# 同源组 OG0008176 写入 OG0008176.transcript.fasta，共 16 条记录。
# 同源组 OG0008177 写入 OG0008177.transcript.fasta，共 16 条记录。
# 同源组 OG0008178 写入 OG0008178.transcript.fasta，共 17 条记录。
# 同源组 OG0008179 写入 OG0008179.transcript.fasta，共 17 条记录。
# 同源组 OG0008183 写入 OG0008183.transcript.fasta，共 16 条记录。
# 同源组 OG0008184 写入 OG0008184.transcript.fasta，共 15 条记录。
# 同源组 OG0008186 写入 OG0008186.transcript.fasta，共 17 条记录。
# 同源组 OG0008192 写入 OG0008192.transcript.fasta，共 16 条记录。
# 同源组 OG0008193 写入 OG0008193.transcript.fasta，共 17 条记录。
# 同源组 OG0008196 写入 OG0008196.transcript.fasta，共 16 条记录。
# 同源组 OG0008198 写入 OG0008198.transcript.fasta，共 16 条记录。
# 同源组 OG0008204 写入 OG0008204.transcript.fasta，共 16 条记录。
# 同源组 OG0008205 写入 OG0008205.transcript.fasta，共 17 条记录。
# 同源组 OG0008212 写入 OG0008212.transcript.fasta，共 15 条记录。
# 同源组 OG0008214 写入 OG0008214.transcript.fasta，共 15 条记录。
# 同源组 OG0008217 写入 OG0008217.transcript.fasta，共 17 条记录。
# 同源组 OG0008221 写入 OG0008221.transcript.fasta，共 17 条记录。
# 同源组 OG0008234 写入 OG0008234.transcript.fasta，共 17 条记录。
# 同源组 OG0008235 写入 OG0008235.transcript.fasta，共 18 条记录。
# 同源组 OG0008238 写入 OG0008238.transcript.fasta，共 17 条记录。
# 同源组 OG0008241 写入 OG0008241.transcript.fasta，共 17 条记录。
# 同源组 OG0008245 写入 OG0008245.transcript.fasta，共 17 条记录。
# 同源组 OG0008256 写入 OG0008256.transcript.fasta，共 16 条记录。
# 同源组 OG0008259 写入 OG0008259.transcript.fasta，共 17 条记录。
# 同源组 OG0008264 写入 OG0008264.transcript.fasta，共 17 条记录。
# 同源组 OG0008266 写入 OG0008266.transcript.fasta，共 17 条记录。
# 同源组 OG0008270 写入 OG0008270.transcript.fasta，共 17 条记录。
# 同源组 OG0008272 写入 OG0008272.transcript.fasta，共 17 条记录。
# 同源组 OG0008273 写入 OG0008273.transcript.fasta，共 16 条记录。
# 同源组 OG0008278 写入 OG0008278.transcript.fasta，共 16 条记录。
# 同源组 OG0008284 写入 OG0008284.transcript.fasta，共 18 条记录。
# 同源组 OG0008285 写入 OG0008285.transcript.fasta，共 17 条记录。
# 同源组 OG0008286 写入 OG0008286.transcript.fasta，共 17 条记录。
# 同源组 OG0008290 写入 OG0008290.transcript.fasta，共 17 条记录。
# 同源组 OG0008292 写入 OG0008292.transcript.fasta，共 16 条记录。
# 同源组 OG0008313 写入 OG0008313.transcript.fasta，共 17 条记录。
# 同源组 OG0008322 写入 OG0008322.transcript.fasta，共 16 条记录。
# 同源组 OG0008327 写入 OG0008327.transcript.fasta，共 16 条记录。
# 同源组 OG0008331 写入 OG0008331.transcript.fasta，共 16 条记录。
# 同源组 OG0008336 写入 OG0008336.transcript.fasta，共 17 条记录。
# 同源组 OG0008337 写入 OG0008337.transcript.fasta，共 17 条记录。
# 同源组 OG0008338 写入 OG0008338.transcript.fasta，共 17 条记录。
# 同源组 OG0008339 写入 OG0008339.transcript.fasta，共 16 条记录。
# 同源组 OG0008342 写入 OG0008342.transcript.fasta，共 18 条记录。
# 同源组 OG0008344 写入 OG0008344.transcript.fasta，共 15 条记录。
# 同源组 OG0008345 写入 OG0008345.transcript.fasta，共 17 条记录。
# 同源组 OG0008346 写入 OG0008346.transcript.fasta，共 15 条记录。
# 同源组 OG0008347 写入 OG0008347.transcript.fasta，共 16 条记录。
# 同源组 OG0008353 写入 OG0008353.transcript.fasta，共 15 条记录。
# 同源组 OG0008357 写入 OG0008357.transcript.fasta，共 16 条记录。
# 同源组 OG0008360 写入 OG0008360.transcript.fasta，共 17 条记录。
# 同源组 OG0008363 写入 OG0008363.transcript.fasta，共 16 条记录。
# 同源组 OG0008364 写入 OG0008364.transcript.fasta，共 16 条记录。
# 同源组 OG0008365 写入 OG0008365.transcript.fasta，共 16 条记录。
# 同源组 OG0008367 写入 OG0008367.transcript.fasta，共 17 条记录。
# 同源组 OG0008371 写入 OG0008371.transcript.fasta，共 17 条记录。
# 同源组 OG0008372 写入 OG0008372.transcript.fasta，共 15 条记录。
# 同源组 OG0008378 写入 OG0008378.transcript.fasta，共 16 条记录。
# 同源组 OG0008384 写入 OG0008384.transcript.fasta，共 18 条记录。
# 同源组 OG0008385 写入 OG0008385.transcript.fasta，共 16 条记录。
# 同源组 OG0008387 写入 OG0008387.transcript.fasta，共 17 条记录。
# 同源组 OG0008388 写入 OG0008388.transcript.fasta，共 16 条记录。
# 同源组 OG0008389 写入 OG0008389.transcript.fasta，共 16 条记录。
# 同源组 OG0008390 写入 OG0008390.transcript.fasta，共 17 条记录。
# 同源组 OG0008391 写入 OG0008391.transcript.fasta，共 17 条记录。
# 同源组 OG0008393 写入 OG0008393.transcript.fasta，共 15 条记录。
# 同源组 OG0008394 写入 OG0008394.transcript.fasta，共 17 条记录。
# 同源组 OG0008395 写入 OG0008395.transcript.fasta，共 16 条记录。
# 同源组 OG0008396 写入 OG0008396.transcript.fasta，共 16 条记录。
# 同源组 OG0008399 写入 OG0008399.transcript.fasta，共 17 条记录。
# 同源组 OG0008401 写入 OG0008401.transcript.fasta，共 17 条记录。
# 同源组 OG0008402 写入 OG0008402.transcript.fasta，共 17 条记录。
# 同源组 OG0008403 写入 OG0008403.transcript.fasta，共 17 条记录。
# 同源组 OG0008404 写入 OG0008404.transcript.fasta，共 17 条记录。
# 同源组 OG0008405 写入 OG0008405.transcript.fasta，共 17 条记录。
# 同源组 OG0008407 写入 OG0008407.transcript.fasta，共 16 条记录。
# 同源组 OG0008408 写入 OG0008408.transcript.fasta，共 16 条记录。
# 同源组 OG0008410 写入 OG0008410.transcript.fasta，共 15 条记录。
# 同源组 OG0008412 写入 OG0008412.transcript.fasta，共 17 条记录。
# 同源组 OG0008415 写入 OG0008415.transcript.fasta，共 16 条记录。
# 同源组 OG0008419 写入 OG0008419.transcript.fasta，共 16 条记录。
# 同源组 OG0008422 写入 OG0008422.transcript.fasta，共 16 条记录。
# 同源组 OG0008424 写入 OG0008424.transcript.fasta，共 16 条记录。
# 同源组 OG0008425 写入 OG0008425.transcript.fasta，共 16 条记录。
# 同源组 OG0008427 写入 OG0008427.transcript.fasta，共 17 条记录。
# 同源组 OG0008432 写入 OG0008432.transcript.fasta，共 16 条记录。
# 同源组 OG0008434 写入 OG0008434.transcript.fasta，共 15 条记录。
# 同源组 OG0008435 写入 OG0008435.transcript.fasta，共 17 条记录。
# 同源组 OG0008438 写入 OG0008438.transcript.fasta，共 17 条记录。
# 同源组 OG0008441 写入 OG0008441.transcript.fasta，共 15 条记录。
# 同源组 OG0008445 写入 OG0008445.transcript.fasta，共 17 条记录。
# 同源组 OG0008446 写入 OG0008446.transcript.fasta，共 16 条记录。
# 同源组 OG0008451 写入 OG0008451.transcript.fasta，共 19 条记录。
# 同源组 OG0008454 写入 OG0008454.transcript.fasta，共 18 条记录。
# 同源组 OG0008455 写入 OG0008455.transcript.fasta，共 17 条记录。
# 同源组 OG0008459 写入 OG0008459.transcript.fasta，共 17 条记录。
# 同源组 OG0008460 写入 OG0008460.transcript.fasta，共 17 条记录。
# 同源组 OG0008461 写入 OG0008461.transcript.fasta，共 17 条记录。
# 同源组 OG0008462 写入 OG0008462.transcript.fasta，共 17 条记录。
# 同源组 OG0008467 写入 OG0008467.transcript.fasta，共 17 条记录。
# 同源组 OG0008469 写入 OG0008469.transcript.fasta，共 17 条记录。
# 同源组 OG0008474 写入 OG0008474.transcript.fasta，共 16 条记录。
# 同源组 OG0008483 写入 OG0008483.transcript.fasta，共 15 条记录。
# 同源组 OG0008485 写入 OG0008485.transcript.fasta，共 16 条记录。
# 同源组 OG0008489 写入 OG0008489.transcript.fasta，共 17 条记录。
# 同源组 OG0008492 写入 OG0008492.transcript.fasta，共 17 条记录。
# 同源组 OG0008508 写入 OG0008508.transcript.fasta，共 17 条记录。
# 同源组 OG0008513 写入 OG0008513.transcript.fasta，共 15 条记录。
# 同源组 OG0008517 写入 OG0008517.transcript.fasta，共 16 条记录。
# 同源组 OG0008525 写入 OG0008525.transcript.fasta，共 17 条记录。
# 同源组 OG0008527 写入 OG0008527.transcript.fasta，共 16 条记录。
# 同源组 OG0008529 写入 OG0008529.transcript.fasta，共 17 条记录。
# 同源组 OG0008536 写入 OG0008536.transcript.fasta，共 16 条记录。
# 同源组 OG0008539 写入 OG0008539.transcript.fasta，共 17 条记录。
# 同源组 OG0008542 写入 OG0008542.transcript.fasta，共 16 条记录。
# 同源组 OG0008543 写入 OG0008543.transcript.fasta，共 17 条记录。
# 同源组 OG0008544 写入 OG0008544.transcript.fasta，共 16 条记录。
# 同源组 OG0008545 写入 OG0008545.transcript.fasta，共 16 条记录。
# 同源组 OG0008547 写入 OG0008547.transcript.fasta，共 17 条记录。
# 同源组 OG0008548 写入 OG0008548.transcript.fasta，共 16 条记录。
# 同源组 OG0008554 写入 OG0008554.transcript.fasta，共 16 条记录。
# 同源组 OG0008555 写入 OG0008555.transcript.fasta，共 17 条记录。
# 同源组 OG0008556 写入 OG0008556.transcript.fasta，共 16 条记录。
# 同源组 OG0008558 写入 OG0008558.transcript.fasta，共 17 条记录。
# 同源组 OG0008563 写入 OG0008563.transcript.fasta，共 17 条记录。
# 同源组 OG0008567 写入 OG0008567.transcript.fasta，共 15 条记录。
# 同源组 OG0008568 写入 OG0008568.transcript.fasta，共 17 条记录。
# 同源组 OG0008572 写入 OG0008572.transcript.fasta，共 16 条记录。
# 同源组 OG0008574 写入 OG0008574.transcript.fasta，共 16 条记录。
# 同源组 OG0008576 写入 OG0008576.transcript.fasta，共 16 条记录。
# 同源组 OG0008577 写入 OG0008577.transcript.fasta，共 17 条记录。
# 同源组 OG0008582 写入 OG0008582.transcript.fasta，共 17 条记录。
# 同源组 OG0008583 写入 OG0008583.transcript.fasta，共 17 条记录。
# 同源组 OG0008585 写入 OG0008585.transcript.fasta，共 17 条记录。
# 同源组 OG0008586 写入 OG0008586.transcript.fasta，共 18 条记录。
# 同源组 OG0008590 写入 OG0008590.transcript.fasta，共 15 条记录。
# 同源组 OG0008591 写入 OG0008591.transcript.fasta，共 17 条记录。
# 同源组 OG0008598 写入 OG0008598.transcript.fasta，共 17 条记录。
# 同源组 OG0008600 写入 OG0008600.transcript.fasta，共 17 条记录。
# 同源组 OG0008606 写入 OG0008606.transcript.fasta，共 17 条记录。
# 同源组 OG0008609 写入 OG0008609.transcript.fasta，共 15 条记录。
# 同源组 OG0008611 写入 OG0008611.transcript.fasta，共 17 条记录。
# 同源组 OG0008612 写入 OG0008612.transcript.fasta，共 15 条记录。
# 同源组 OG0008613 写入 OG0008613.transcript.fasta，共 17 条记录。
# 同源组 OG0008619 写入 OG0008619.transcript.fasta，共 17 条记录。
# 同源组 OG0008620 写入 OG0008620.transcript.fasta，共 17 条记录。
# 同源组 OG0008622 写入 OG0008622.transcript.fasta，共 16 条记录。
# 同源组 OG0008623 写入 OG0008623.transcript.fasta，共 17 条记录。
# 同源组 OG0008624 写入 OG0008624.transcript.fasta，共 15 条记录。
# 同源组 OG0008626 写入 OG0008626.transcript.fasta，共 16 条记录。
# 同源组 OG0008627 写入 OG0008627.transcript.fasta，共 16 条记录。
# 同源组 OG0008629 写入 OG0008629.transcript.fasta，共 17 条记录。
# 同源组 OG0008631 写入 OG0008631.transcript.fasta，共 17 条记录。
# 同源组 OG0008633 写入 OG0008633.transcript.fasta，共 16 条记录。
# 同源组 OG0008634 写入 OG0008634.transcript.fasta，共 15 条记录。
# 同源组 OG0008635 写入 OG0008635.transcript.fasta，共 17 条记录。
# 同源组 OG0008637 写入 OG0008637.transcript.fasta，共 17 条记录。
# 同源组 OG0008642 写入 OG0008642.transcript.fasta，共 15 条记录。
# 同源组 OG0008643 写入 OG0008643.transcript.fasta，共 16 条记录。
# 同源组 OG0008645 写入 OG0008645.transcript.fasta，共 16 条记录。
# 同源组 OG0008647 写入 OG0008647.transcript.fasta，共 15 条记录。
# 同源组 OG0008651 写入 OG0008651.transcript.fasta，共 17 条记录。
# 同源组 OG0008654 写入 OG0008654.transcript.fasta，共 16 条记录。
# 同源组 OG0008655 写入 OG0008655.transcript.fasta，共 17 条记录。
# 同源组 OG0008656 写入 OG0008656.transcript.fasta，共 17 条记录。
# 同源组 OG0008658 写入 OG0008658.transcript.fasta，共 17 条记录。
# 同源组 OG0008659 写入 OG0008659.transcript.fasta，共 15 条记录。
# 同源组 OG0008662 写入 OG0008662.transcript.fasta，共 15 条记录。
# 同源组 OG0008665 写入 OG0008665.transcript.fasta，共 16 条记录。
# 同源组 OG0008667 写入 OG0008667.transcript.fasta，共 16 条记录。
# 同源组 OG0008669 写入 OG0008669.transcript.fasta，共 17 条记录。
# 同源组 OG0008671 写入 OG0008671.transcript.fasta，共 16 条记录。
# 同源组 OG0008672 写入 OG0008672.transcript.fasta，共 17 条记录。
# 同源组 OG0008673 写入 OG0008673.transcript.fasta，共 17 条记录。
# 同源组 OG0008676 写入 OG0008676.transcript.fasta，共 17 条记录。
# 同源组 OG0008678 写入 OG0008678.transcript.fasta，共 16 条记录。
# 同源组 OG0008683 写入 OG0008683.transcript.fasta，共 18 条记录。
# 同源组 OG0008686 写入 OG0008686.transcript.fasta，共 16 条记录。
# 同源组 OG0008690 写入 OG0008690.transcript.fasta，共 17 条记录。
# 同源组 OG0008701 写入 OG0008701.transcript.fasta，共 16 条记录。
# 同源组 OG0008708 写入 OG0008708.transcript.fasta，共 17 条记录。
# 同源组 OG0008711 写入 OG0008711.transcript.fasta，共 17 条记录。
# 同源组 OG0008714 写入 OG0008714.transcript.fasta，共 16 条记录。
# 同源组 OG0008717 写入 OG0008717.transcript.fasta，共 21 条记录。
# 同源组 OG0008718 写入 OG0008718.transcript.fasta，共 17 条记录。
# 同源组 OG0008720 写入 OG0008720.transcript.fasta，共 18 条记录。
# 同源组 OG0008726 写入 OG0008726.transcript.fasta，共 15 条记录。
# 同源组 OG0008739 写入 OG0008739.transcript.fasta，共 17 条记录。
# 同源组 OG0008740 写入 OG0008740.transcript.fasta，共 17 条记录。
# 同源组 OG0008744 写入 OG0008744.transcript.fasta，共 17 条记录。
# 同源组 OG0008753 写入 OG0008753.transcript.fasta，共 16 条记录。
# 同源组 OG0008755 写入 OG0008755.transcript.fasta，共 17 条记录。
# 同源组 OG0008760 写入 OG0008760.transcript.fasta，共 16 条记录。
# 同源组 OG0008762 写入 OG0008762.transcript.fasta，共 16 条记录。
# 同源组 OG0008764 写入 OG0008764.transcript.fasta，共 15 条记录。
# 同源组 OG0008765 写入 OG0008765.transcript.fasta，共 17 条记录。
# 同源组 OG0008766 写入 OG0008766.transcript.fasta，共 16 条记录。
# 同源组 OG0008767 写入 OG0008767.transcript.fasta，共 16 条记录。
# 同源组 OG0008770 写入 OG0008770.transcript.fasta，共 17 条记录。
# 同源组 OG0008771 写入 OG0008771.transcript.fasta，共 17 条记录。
# 同源组 OG0008773 写入 OG0008773.transcript.fasta，共 15 条记录。
# 同源组 OG0008778 写入 OG0008778.transcript.fasta，共 17 条记录。
# 同源组 OG0008780 写入 OG0008780.transcript.fasta，共 17 条记录。
# 同源组 OG0008782 写入 OG0008782.transcript.fasta，共 17 条记录。
# 同源组 OG0008783 写入 OG0008783.transcript.fasta，共 17 条记录。
# 同源组 OG0008784 写入 OG0008784.transcript.fasta，共 17 条记录。
# 同源组 OG0008785 写入 OG0008785.transcript.fasta，共 17 条记录。
# 同源组 OG0008786 写入 OG0008786.transcript.fasta，共 17 条记录。
# 同源组 OG0008787 写入 OG0008787.transcript.fasta，共 16 条记录。
# 同源组 OG0008792 写入 OG0008792.transcript.fasta，共 17 条记录。
# 同源组 OG0008794 写入 OG0008794.transcript.fasta，共 17 条记录。
# 同源组 OG0008797 写入 OG0008797.transcript.fasta，共 16 条记录。
# 同源组 OG0008798 写入 OG0008798.transcript.fasta，共 17 条记录。
# 同源组 OG0008800 写入 OG0008800.transcript.fasta，共 16 条记录。
# 同源组 OG0008804 写入 OG0008804.transcript.fasta，共 15 条记录。
# 同源组 OG0008805 写入 OG0008805.transcript.fasta，共 17 条记录。
# 同源组 OG0008806 写入 OG0008806.transcript.fasta，共 17 条记录。
# 同源组 OG0008808 写入 OG0008808.transcript.fasta，共 16 条记录。
# 同源组 OG0008815 写入 OG0008815.transcript.fasta，共 15 条记录。
# 同源组 OG0008816 写入 OG0008816.transcript.fasta，共 16 条记录。
# 同源组 OG0008817 写入 OG0008817.transcript.fasta，共 16 条记录。
# 同源组 OG0008818 写入 OG0008818.transcript.fasta，共 17 条记录。
# 同源组 OG0008819 写入 OG0008819.transcript.fasta，共 17 条记录。
# 同源组 OG0008821 写入 OG0008821.transcript.fasta，共 17 条记录。
# 同源组 OG0008824 写入 OG0008824.transcript.fasta，共 16 条记录。
# 同源组 OG0008826 写入 OG0008826.transcript.fasta，共 16 条记录。
# 同源组 OG0008827 写入 OG0008827.transcript.fasta，共 18 条记录。
# 同源组 OG0008828 写入 OG0008828.transcript.fasta，共 17 条记录。
# 同源组 OG0008829 写入 OG0008829.transcript.fasta，共 16 条记录。
# 同源组 OG0008831 写入 OG0008831.transcript.fasta，共 16 条记录。
# 同源组 OG0008832 写入 OG0008832.transcript.fasta，共 17 条记录。
# 同源组 OG0008836 写入 OG0008836.transcript.fasta，共 17 条记录。
# 同源组 OG0008837 写入 OG0008837.transcript.fasta，共 17 条记录。
# 同源组 OG0008838 写入 OG0008838.transcript.fasta，共 15 条记录。
# 同源组 OG0008839 写入 OG0008839.transcript.fasta，共 16 条记录。
# 同源组 OG0008841 写入 OG0008841.transcript.fasta，共 17 条记录。
# 同源组 OG0008848 写入 OG0008848.transcript.fasta，共 16 条记录。
# 同源组 OG0008849 写入 OG0008849.transcript.fasta，共 16 条记录。
# 同源组 OG0008851 写入 OG0008851.transcript.fasta，共 16 条记录。
# 同源组 OG0008854 写入 OG0008854.transcript.fasta，共 16 条记录。
# 同源组 OG0008856 写入 OG0008856.transcript.fasta，共 18 条记录。
# 同源组 OG0008858 写入 OG0008858.transcript.fasta，共 16 条记录。
# 同源组 OG0008859 写入 OG0008859.transcript.fasta，共 17 条记录。
# 同源组 OG0008872 写入 OG0008872.transcript.fasta，共 18 条记录。
# 同源组 OG0008874 写入 OG0008874.transcript.fasta，共 16 条记录。
# 同源组 OG0008877 写入 OG0008877.transcript.fasta，共 17 条记录。
# 同源组 OG0008881 写入 OG0008881.transcript.fasta，共 15 条记录。
# 同源组 OG0008885 写入 OG0008885.transcript.fasta，共 17 条记录。
# 同源组 OG0008886 写入 OG0008886.transcript.fasta，共 15 条记录。
# 同源组 OG0008890 写入 OG0008890.transcript.fasta，共 16 条记录。
# 同源组 OG0008895 写入 OG0008895.transcript.fasta，共 17 条记录。
# 同源组 OG0008901 写入 OG0008901.transcript.fasta，共 17 条记录。
# 同源组 OG0008903 写入 OG0008903.transcript.fasta，共 15 条记录。
# 同源组 OG0008906 写入 OG0008906.transcript.fasta，共 16 条记录。
# 同源组 OG0008917 写入 OG0008917.transcript.fasta，共 16 条记录。
# 同源组 OG0008919 写入 OG0008919.transcript.fasta，共 16 条记录。
# 同源组 OG0008931 写入 OG0008931.transcript.fasta，共 15 条记录。
# 同源组 OG0008933 写入 OG0008933.transcript.fasta，共 15 条记录。
# 同源组 OG0008939 写入 OG0008939.transcript.fasta，共 17 条记录。
# 同源组 OG0008940 写入 OG0008940.transcript.fasta，共 15 条记录。
# 同源组 OG0008941 写入 OG0008941.transcript.fasta，共 17 条记录。
# 同源组 OG0008942 写入 OG0008942.transcript.fasta，共 17 条记录。
# 同源组 OG0008943 写入 OG0008943.transcript.fasta，共 16 条记录。
# 同源组 OG0008948 写入 OG0008948.transcript.fasta，共 16 条记录。
# 同源组 OG0008949 写入 OG0008949.transcript.fasta，共 17 条记录。
# 同源组 OG0008951 写入 OG0008951.transcript.fasta，共 17 条记录。
# 同源组 OG0008955 写入 OG0008955.transcript.fasta，共 17 条记录。
# 同源组 OG0008958 写入 OG0008958.transcript.fasta，共 15 条记录。
# 同源组 OG0008960 写入 OG0008960.transcript.fasta，共 20 条记录。
# 同源组 OG0008963 写入 OG0008963.transcript.fasta，共 17 条记录。
# 同源组 OG0008964 写入 OG0008964.transcript.fasta，共 17 条记录。
# 同源组 OG0008965 写入 OG0008965.transcript.fasta，共 16 条记录。
# 同源组 OG0008967 写入 OG0008967.transcript.fasta，共 17 条记录。
# 同源组 OG0008968 写入 OG0008968.transcript.fasta，共 17 条记录。
# 同源组 OG0008969 写入 OG0008969.transcript.fasta，共 17 条记录。
# 同源组 OG0008972 写入 OG0008972.transcript.fasta，共 17 条记录。
# 同源组 OG0008975 写入 OG0008975.transcript.fasta，共 17 条记录。
# 同源组 OG0008978 写入 OG0008978.transcript.fasta，共 16 条记录。
# 同源组 OG0008979 写入 OG0008979.transcript.fasta，共 17 条记录。
# 同源组 OG0008981 写入 OG0008981.transcript.fasta，共 18 条记录。
# 同源组 OG0008982 写入 OG0008982.transcript.fasta，共 16 条记录。
# 同源组 OG0008984 写入 OG0008984.transcript.fasta，共 17 条记录。
# 同源组 OG0008985 写入 OG0008985.transcript.fasta，共 15 条记录。
# 同源组 OG0008987 写入 OG0008987.transcript.fasta，共 17 条记录。
# 同源组 OG0008988 写入 OG0008988.transcript.fasta，共 15 条记录。
# 同源组 OG0008991 写入 OG0008991.transcript.fasta，共 15 条记录。
# 同源组 OG0008992 写入 OG0008992.transcript.fasta，共 15 条记录。
# 同源组 OG0008993 写入 OG0008993.transcript.fasta，共 15 条记录。
# 同源组 OG0008994 写入 OG0008994.transcript.fasta，共 16 条记录。
# 同源组 OG0008999 写入 OG0008999.transcript.fasta，共 17 条记录。
# 同源组 OG0009000 写入 OG0009000.transcript.fasta，共 16 条记录。
# 同源组 OG0009001 写入 OG0009001.transcript.fasta，共 16 条记录。
# 同源组 OG0009004 写入 OG0009004.transcript.fasta，共 16 条记录。
# 同源组 OG0009008 写入 OG0009008.transcript.fasta，共 17 条记录。
# 同源组 OG0009014 写入 OG0009014.transcript.fasta，共 15 条记录。
# 同源组 OG0009016 写入 OG0009016.transcript.fasta，共 17 条记录。
# 同源组 OG0009018 写入 OG0009018.transcript.fasta，共 16 条记录。
# 同源组 OG0009019 写入 OG0009019.transcript.fasta，共 15 条记录。
# 同源组 OG0009025 写入 OG0009025.transcript.fasta，共 16 条记录。
# 同源组 OG0009027 写入 OG0009027.transcript.fasta，共 16 条记录。
# 同源组 OG0009033 写入 OG0009033.transcript.fasta，共 15 条记录。
# 同源组 OG0009034 写入 OG0009034.transcript.fasta，共 15 条记录。
# 同源组 OG0009035 写入 OG0009035.transcript.fasta，共 16 条记录。
# 同源组 OG0009037 写入 OG0009037.transcript.fasta，共 18 条记录。
# 同源组 OG0009038 写入 OG0009038.transcript.fasta，共 15 条记录。
# 同源组 OG0009040 写入 OG0009040.transcript.fasta，共 15 条记录。
# 同源组 OG0009042 写入 OG0009042.transcript.fasta，共 15 条记录。
# 同源组 OG0009047 写入 OG0009047.transcript.fasta，共 17 条记录。
# 同源组 OG0009051 写入 OG0009051.transcript.fasta，共 17 条记录。
# 同源组 OG0009066 写入 OG0009066.transcript.fasta，共 15 条记录。
# 同源组 OG0009079 写入 OG0009079.transcript.fasta，共 16 条记录。
# 同源组 OG0009082 写入 OG0009082.transcript.fasta，共 15 条记录。
# 同源组 OG0009083 写入 OG0009083.transcript.fasta，共 19 条记录。
# 同源组 OG0009086 写入 OG0009086.transcript.fasta，共 17 条记录。
# 同源组 OG0009099 写入 OG0009099.transcript.fasta，共 15 条记录。
# 同源组 OG0009101 写入 OG0009101.transcript.fasta，共 15 条记录。
# 同源组 OG0009102 写入 OG0009102.transcript.fasta，共 15 条记录。
# 同源组 OG0009103 写入 OG0009103.transcript.fasta，共 16 条记录。
# 同源组 OG0009104 写入 OG0009104.transcript.fasta，共 17 条记录。
# 同源组 OG0009108 写入 OG0009108.transcript.fasta，共 17 条记录。
# 同源组 OG0009109 写入 OG0009109.transcript.fasta，共 15 条记录。
# 同源组 OG0009112 写入 OG0009112.transcript.fasta，共 16 条记录。
# 同源组 OG0009114 写入 OG0009114.transcript.fasta，共 16 条记录。
# 同源组 OG0009118 写入 OG0009118.transcript.fasta，共 16 条记录。
# 同源组 OG0009119 写入 OG0009119.transcript.fasta，共 16 条记录。
# 同源组 OG0009123 写入 OG0009123.transcript.fasta，共 16 条记录。
# 同源组 OG0009126 写入 OG0009126.transcript.fasta，共 15 条记录。
# 同源组 OG0009131 写入 OG0009131.transcript.fasta，共 17 条记录。
# 同源组 OG0009132 写入 OG0009132.transcript.fasta，共 16 条记录。
# 同源组 OG0009133 写入 OG0009133.transcript.fasta，共 15 条记录。
# 同源组 OG0009134 写入 OG0009134.transcript.fasta，共 16 条记录。
# 同源组 OG0009135 写入 OG0009135.transcript.fasta，共 17 条记录。
# 同源组 OG0009140 写入 OG0009140.transcript.fasta，共 17 条记录。
# 同源组 OG0009144 写入 OG0009144.transcript.fasta，共 15 条记录。
# 同源组 OG0009148 写入 OG0009148.transcript.fasta，共 16 条记录。
# 同源组 OG0009152 写入 OG0009152.transcript.fasta，共 17 条记录。
# 同源组 OG0009153 写入 OG0009153.transcript.fasta，共 18 条记录。
# 同源组 OG0009156 写入 OG0009156.transcript.fasta，共 17 条记录。
# 同源组 OG0009162 写入 OG0009162.transcript.fasta，共 17 条记录。
# 同源组 OG0009164 写入 OG0009164.transcript.fasta，共 17 条记录。
# 同源组 OG0009165 写入 OG0009165.transcript.fasta，共 16 条记录。
# 同源组 OG0009170 写入 OG0009170.transcript.fasta，共 17 条记录。
# 同源组 OG0009172 写入 OG0009172.transcript.fasta，共 15 条记录。
# 同源组 OG0009181 写入 OG0009181.transcript.fasta，共 17 条记录。
# 同源组 OG0009184 写入 OG0009184.transcript.fasta，共 16 条记录。
# 同源组 OG0009198 写入 OG0009198.transcript.fasta，共 16 条记录。
# 同源组 OG0009203 写入 OG0009203.transcript.fasta，共 17 条记录。
# 同源组 OG0009206 写入 OG0009206.transcript.fasta，共 17 条记录。
# 同源组 OG0009211 写入 OG0009211.transcript.fasta，共 15 条记录。
# 同源组 OG0009212 写入 OG0009212.transcript.fasta，共 17 条记录。
# 同源组 OG0009213 写入 OG0009213.transcript.fasta，共 15 条记录。
# 同源组 OG0009218 写入 OG0009218.transcript.fasta，共 17 条记录。
# 同源组 OG0009219 写入 OG0009219.transcript.fasta，共 15 条记录。
# 同源组 OG0009220 写入 OG0009220.transcript.fasta，共 17 条记录。
# 同源组 OG0009224 写入 OG0009224.transcript.fasta，共 16 条记录。
# 同源组 OG0009226 写入 OG0009226.transcript.fasta，共 16 条记录。
# 同源组 OG0009229 写入 OG0009229.transcript.fasta，共 15 条记录。
# 同源组 OG0009241 写入 OG0009241.transcript.fasta，共 18 条记录。
# 同源组 OG0009243 写入 OG0009243.transcript.fasta，共 16 条记录。
# 同源组 OG0009246 写入 OG0009246.transcript.fasta，共 16 条记录。
# 同源组 OG0009247 写入 OG0009247.transcript.fasta，共 17 条记录。
# 同源组 OG0009249 写入 OG0009249.transcript.fasta，共 17 条记录。
# 同源组 OG0009251 写入 OG0009251.transcript.fasta，共 16 条记录。
# 同源组 OG0009256 写入 OG0009256.transcript.fasta，共 17 条记录。
# 同源组 OG0009257 写入 OG0009257.transcript.fasta，共 16 条记录。
# 同源组 OG0009259 写入 OG0009259.transcript.fasta，共 17 条记录。
# 同源组 OG0009260 写入 OG0009260.transcript.fasta，共 16 条记录。
# 同源组 OG0009261 写入 OG0009261.transcript.fasta，共 16 条记录。
# 同源组 OG0009262 写入 OG0009262.transcript.fasta，共 17 条记录。
# 同源组 OG0009263 写入 OG0009263.transcript.fasta，共 15 条记录。
# 同源组 OG0009264 写入 OG0009264.transcript.fasta，共 17 条记录。
# 同源组 OG0009265 写入 OG0009265.transcript.fasta，共 16 条记录。
# 同源组 OG0009270 写入 OG0009270.transcript.fasta，共 15 条记录。
# 同源组 OG0009271 写入 OG0009271.transcript.fasta，共 16 条记录。
# 同源组 OG0009282 写入 OG0009282.transcript.fasta，共 16 条记录。
# 同源组 OG0009283 写入 OG0009283.transcript.fasta，共 15 条记录。
# 同源组 OG0009284 写入 OG0009284.transcript.fasta，共 17 条记录。
# 同源组 OG0009286 写入 OG0009286.transcript.fasta，共 16 条记录。
# 同源组 OG0009287 写入 OG0009287.transcript.fasta，共 16 条记录。
# 同源组 OG0009288 写入 OG0009288.transcript.fasta，共 17 条记录。
# 同源组 OG0009290 写入 OG0009290.transcript.fasta，共 15 条记录。
# 同源组 OG0009292 写入 OG0009292.transcript.fasta，共 15 条记录。
# 同源组 OG0009293 写入 OG0009293.transcript.fasta，共 17 条记录。
# 同源组 OG0009294 写入 OG0009294.transcript.fasta，共 17 条记录。
# 同源组 OG0009295 写入 OG0009295.transcript.fasta，共 17 条记录。
# 同源组 OG0009296 写入 OG0009296.transcript.fasta，共 17 条记录。
# 同源组 OG0009300 写入 OG0009300.transcript.fasta，共 17 条记录。
# 同源组 OG0009301 写入 OG0009301.transcript.fasta，共 15 条记录。
# 同源组 OG0009302 写入 OG0009302.transcript.fasta，共 17 条记录。
# 同源组 OG0009305 写入 OG0009305.transcript.fasta，共 16 条记录。
# 同源组 OG0009306 写入 OG0009306.transcript.fasta，共 16 条记录。
# 同源组 OG0009308 写入 OG0009308.transcript.fasta，共 18 条记录。
# 同源组 OG0009309 写入 OG0009309.transcript.fasta，共 16 条记录。
# 同源组 OG0009313 写入 OG0009313.transcript.fasta，共 15 条记录。
# 同源组 OG0009316 写入 OG0009316.transcript.fasta，共 17 条记录。
# 同源组 OG0009317 写入 OG0009317.transcript.fasta，共 15 条记录。
# 同源组 OG0009318 写入 OG0009318.transcript.fasta，共 15 条记录。
# 同源组 OG0009319 写入 OG0009319.transcript.fasta，共 16 条记录。
# 同源组 OG0009320 写入 OG0009320.transcript.fasta，共 15 条记录。
# 同源组 OG0009321 写入 OG0009321.transcript.fasta，共 16 条记录。
# 同源组 OG0009322 写入 OG0009322.transcript.fasta，共 16 条记录。
# 同源组 OG0009323 写入 OG0009323.transcript.fasta，共 17 条记录。
# 同源组 OG0009324 写入 OG0009324.transcript.fasta，共 17 条记录。
# 同源组 OG0009325 写入 OG0009325.transcript.fasta，共 17 条记录。
# 同源组 OG0009326 写入 OG0009326.transcript.fasta，共 16 条记录。
# 同源组 OG0009335 写入 OG0009335.transcript.fasta，共 17 条记录。
# 同源组 OG0009336 写入 OG0009336.transcript.fasta，共 17 条记录。
# 同源组 OG0009339 写入 OG0009339.transcript.fasta，共 16 条记录。
# 同源组 OG0009346 写入 OG0009346.transcript.fasta，共 17 条记录。
# 同源组 OG0009348 写入 OG0009348.transcript.fasta，共 16 条记录。
# 同源组 OG0009351 写入 OG0009351.transcript.fasta，共 16 条记录。
# 同源组 OG0009362 写入 OG0009362.transcript.fasta，共 15 条记录。
# 同源组 OG0009365 写入 OG0009365.transcript.fasta，共 17 条记录。
# 同源组 OG0009368 写入 OG0009368.transcript.fasta，共 17 条记录。
# 同源组 OG0009369 写入 OG0009369.transcript.fasta，共 16 条记录。
# 同源组 OG0009372 写入 OG0009372.transcript.fasta，共 15 条记录。
# 同源组 OG0009373 写入 OG0009373.transcript.fasta，共 15 条记录。
# 同源组 OG0009376 写入 OG0009376.transcript.fasta，共 16 条记录。
# 同源组 OG0009377 写入 OG0009377.transcript.fasta，共 16 条记录。
# 同源组 OG0009380 写入 OG0009380.transcript.fasta，共 17 条记录。
# 同源组 OG0009382 写入 OG0009382.transcript.fasta，共 17 条记录。
# 同源组 OG0009383 写入 OG0009383.transcript.fasta，共 15 条记录。
# 同源组 OG0009390 写入 OG0009390.transcript.fasta，共 17 条记录。
# 同源组 OG0009393 写入 OG0009393.transcript.fasta，共 16 条记录。
# 同源组 OG0009402 写入 OG0009402.transcript.fasta，共 16 条记录。
# 同源组 OG0009405 写入 OG0009405.transcript.fasta，共 16 条记录。
# 同源组 OG0009408 写入 OG0009408.transcript.fasta，共 16 条记录。
# 同源组 OG0009412 写入 OG0009412.transcript.fasta，共 17 条记录。
# 同源组 OG0009414 写入 OG0009414.transcript.fasta，共 16 条记录。
# 同源组 OG0009418 写入 OG0009418.transcript.fasta，共 16 条记录。
# 同源组 OG0009426 写入 OG0009426.transcript.fasta，共 17 条记录。
# 同源组 OG0009427 写入 OG0009427.transcript.fasta，共 16 条记录。
# 同源组 OG0009429 写入 OG0009429.transcript.fasta，共 15 条记录。
# 同源组 OG0009431 写入 OG0009431.transcript.fasta，共 16 条记录。
# 同源组 OG0009432 写入 OG0009432.transcript.fasta，共 16 条记录。
# 同源组 OG0009434 写入 OG0009434.transcript.fasta，共 16 条记录。
# 同源组 OG0009435 写入 OG0009435.transcript.fasta，共 17 条记录。
# 同源组 OG0009437 写入 OG0009437.transcript.fasta，共 16 条记录。
# 同源组 OG0009441 写入 OG0009441.transcript.fasta，共 16 条记录。
# 同源组 OG0009444 写入 OG0009444.transcript.fasta，共 16 条记录。
# 同源组 OG0009445 写入 OG0009445.transcript.fasta，共 15 条记录。
# 同源组 OG0009447 写入 OG0009447.transcript.fasta，共 16 条记录。
# 同源组 OG0009449 写入 OG0009449.transcript.fasta，共 16 条记录。
# 同源组 OG0009465 写入 OG0009465.transcript.fasta，共 16 条记录。
# 同源组 OG0009479 写入 OG0009479.transcript.fasta，共 16 条记录。
# 同源组 OG0009480 写入 OG0009480.transcript.fasta，共 15 条记录。
# 同源组 OG0009482 写入 OG0009482.transcript.fasta，共 16 条记录。
# 同源组 OG0009483 写入 OG0009483.transcript.fasta，共 16 条记录。
# 同源组 OG0009484 写入 OG0009484.transcript.fasta，共 16 条记录。
# 同源组 OG0009492 写入 OG0009492.transcript.fasta，共 17 条记录。
# 同源组 OG0009495 写入 OG0009495.transcript.fasta，共 16 条记录。
# 同源组 OG0009498 写入 OG0009498.transcript.fasta，共 17 条记录。
# 同源组 OG0009502 写入 OG0009502.transcript.fasta，共 17 条记录。
# 同源组 OG0009503 写入 OG0009503.transcript.fasta，共 16 条记录。
# 同源组 OG0009504 写入 OG0009504.transcript.fasta，共 17 条记录。
# 同源组 OG0009508 写入 OG0009508.transcript.fasta，共 16 条记录。
# 同源组 OG0009511 写入 OG0009511.transcript.fasta，共 15 条记录。
# 同源组 OG0009512 写入 OG0009512.transcript.fasta，共 16 条记录。
# 同源组 OG0009525 写入 OG0009525.transcript.fasta，共 15 条记录。
# 同源组 OG0009527 写入 OG0009527.transcript.fasta，共 15 条记录。
# 同源组 OG0009529 写入 OG0009529.transcript.fasta，共 16 条记录。
# 同源组 OG0009530 写入 OG0009530.transcript.fasta，共 15 条记录。
# 同源组 OG0009531 写入 OG0009531.transcript.fasta，共 15 条记录。
# 同源组 OG0009535 写入 OG0009535.transcript.fasta，共 17 条记录。
# 同源组 OG0009539 写入 OG0009539.transcript.fasta，共 15 条记录。
# 同源组 OG0009540 写入 OG0009540.transcript.fasta，共 16 条记录。
# 同源组 OG0009542 写入 OG0009542.transcript.fasta，共 16 条记录。
# 同源组 OG0009547 写入 OG0009547.transcript.fasta，共 16 条记录。
# 同源组 OG0009550 写入 OG0009550.transcript.fasta，共 17 条记录。
# 同源组 OG0009560 写入 OG0009560.transcript.fasta，共 16 条记录。
# 同源组 OG0009561 写入 OG0009561.transcript.fasta，共 15 条记录。
# 同源组 OG0009565 写入 OG0009565.transcript.fasta，共 17 条记录。
# 同源组 OG0009574 写入 OG0009574.transcript.fasta，共 16 条记录。
# 同源组 OG0009579 写入 OG0009579.transcript.fasta，共 16 条记录。
# 同源组 OG0009583 写入 OG0009583.transcript.fasta，共 16 条记录。
# 同源组 OG0009585 写入 OG0009585.transcript.fasta，共 16 条记录。
# 同源组 OG0009586 写入 OG0009586.transcript.fasta，共 15 条记录。
# 同源组 OG0009598 写入 OG0009598.transcript.fasta，共 15 条记录。
# 同源组 OG0009600 写入 OG0009600.transcript.fasta，共 17 条记录。
# 同源组 OG0009601 写入 OG0009601.transcript.fasta，共 17 条记录。
# 同源组 OG0009603 写入 OG0009603.transcript.fasta，共 17 条记录。
# 同源组 OG0009611 写入 OG0009611.transcript.fasta，共 17 条记录。
# 同源组 OG0009623 写入 OG0009623.transcript.fasta，共 15 条记录。
# 同源组 OG0009637 写入 OG0009637.transcript.fasta，共 16 条记录。
# 同源组 OG0009640 写入 OG0009640.transcript.fasta，共 17 条记录。
# 同源组 OG0009641 写入 OG0009641.transcript.fasta，共 15 条记录。
# 同源组 OG0009642 写入 OG0009642.transcript.fasta，共 15 条记录。
# 同源组 OG0009644 写入 OG0009644.transcript.fasta，共 16 条记录。
# 同源组 OG0009645 写入 OG0009645.transcript.fasta，共 17 条记录。
# 同源组 OG0009652 写入 OG0009652.transcript.fasta，共 16 条记录。
# 同源组 OG0009660 写入 OG0009660.transcript.fasta，共 15 条记录。
# 同源组 OG0009661 写入 OG0009661.transcript.fasta，共 18 条记录。
# 同源组 OG0009663 写入 OG0009663.transcript.fasta，共 17 条记录。
# 同源组 OG0009665 写入 OG0009665.transcript.fasta，共 16 条记录。
# 同源组 OG0009671 写入 OG0009671.transcript.fasta，共 15 条记录。
# 同源组 OG0009673 写入 OG0009673.transcript.fasta，共 17 条记录。
# 同源组 OG0009676 写入 OG0009676.transcript.fasta，共 15 条记录。
# 同源组 OG0009678 写入 OG0009678.transcript.fasta，共 15 条记录。
# 同源组 OG0009680 写入 OG0009680.transcript.fasta，共 17 条记录。
# 同源组 OG0009684 写入 OG0009684.transcript.fasta，共 16 条记录。
# 同源组 OG0009685 写入 OG0009685.transcript.fasta，共 16 条记录。
# 同源组 OG0009692 写入 OG0009692.transcript.fasta，共 15 条记录。
# 同源组 OG0009693 写入 OG0009693.transcript.fasta，共 15 条记录。
# 同源组 OG0009699 写入 OG0009699.transcript.fasta，共 15 条记录。
# 同源组 OG0009700 写入 OG0009700.transcript.fasta，共 16 条记录。
# 同源组 OG0009701 写入 OG0009701.transcript.fasta，共 16 条记录。
# 同源组 OG0009703 写入 OG0009703.transcript.fasta，共 15 条记录。
# 同源组 OG0009704 写入 OG0009704.transcript.fasta，共 16 条记录。
# 同源组 OG0009705 写入 OG0009705.transcript.fasta，共 16 条记录。
# 同源组 OG0009708 写入 OG0009708.transcript.fasta，共 16 条记录。
# 同源组 OG0009713 写入 OG0009713.transcript.fasta，共 15 条记录。
# 同源组 OG0009718 写入 OG0009718.transcript.fasta，共 15 条记录。
# 同源组 OG0009735 写入 OG0009735.transcript.fasta，共 15 条记录。
# 同源组 OG0009736 写入 OG0009736.transcript.fasta，共 16 条记录。
# 同源组 OG0009738 写入 OG0009738.transcript.fasta，共 17 条记录。
# 同源组 OG0009740 写入 OG0009740.transcript.fasta，共 16 条记录。
# 同源组 OG0009751 写入 OG0009751.transcript.fasta，共 15 条记录。
# 同源组 OG0009756 写入 OG0009756.transcript.fasta，共 17 条记录。
# 同源组 OG0009757 写入 OG0009757.transcript.fasta，共 17 条记录。
# 同源组 OG0009770 写入 OG0009770.transcript.fasta，共 15 条记录。
# 同源组 OG0009771 写入 OG0009771.transcript.fasta，共 15 条记录。
# 同源组 OG0009775 写入 OG0009775.transcript.fasta，共 17 条记录。
# 同源组 OG0009776 写入 OG0009776.transcript.fasta，共 15 条记录。
# 同源组 OG0009778 写入 OG0009778.transcript.fasta，共 18 条记录。
# 同源组 OG0009779 写入 OG0009779.transcript.fasta，共 17 条记录。
# 同源组 OG0009781 写入 OG0009781.transcript.fasta，共 17 条记录。
# 同源组 OG0009783 写入 OG0009783.transcript.fasta，共 16 条记录。
# 同源组 OG0009788 写入 OG0009788.transcript.fasta，共 15 条记录。
# 同源组 OG0009796 写入 OG0009796.transcript.fasta，共 16 条记录。
# 同源组 OG0009803 写入 OG0009803.transcript.fasta，共 15 条记录。
# 同源组 OG0009815 写入 OG0009815.transcript.fasta，共 15 条记录。
# 同源组 OG0009820 写入 OG0009820.transcript.fasta，共 17 条记录。
# 同源组 OG0009831 写入 OG0009831.transcript.fasta，共 15 条记录。
# 同源组 OG0009834 写入 OG0009834.transcript.fasta，共 15 条记录。
# 同源组 OG0009835 写入 OG0009835.transcript.fasta，共 15 条记录。
# 同源组 OG0009841 写入 OG0009841.transcript.fasta，共 16 条记录。
# 同源组 OG0009842 写入 OG0009842.transcript.fasta，共 15 条记录。
# 同源组 OG0009844 写入 OG0009844.transcript.fasta，共 17 条记录。
# 同源组 OG0009861 写入 OG0009861.transcript.fasta，共 17 条记录。
# 同源组 OG0009877 写入 OG0009877.transcript.fasta，共 15 条记录。
# 同源组 OG0009878 写入 OG0009878.transcript.fasta，共 16 条记录。
# 同源组 OG0009883 写入 OG0009883.transcript.fasta，共 16 条记录。
# 同源组 OG0009887 写入 OG0009887.transcript.fasta，共 15 条记录。
# 同源组 OG0009906 写入 OG0009906.transcript.fasta，共 17 条记录。
# 同源组 OG0009918 写入 OG0009918.transcript.fasta，共 15 条记录。
# 同源组 OG0009919 写入 OG0009919.transcript.fasta，共 16 条记录。
# 同源组 OG0009948 写入 OG0009948.transcript.fasta，共 17 条记录。
# 同源组 OG0009952 写入 OG0009952.transcript.fasta，共 16 条记录。
# 同源组 OG0009953 写入 OG0009953.transcript.fasta，共 15 条记录。
# 同源组 OG0009957 写入 OG0009957.transcript.fasta，共 15 条记录。
# 同源组 OG0009962 写入 OG0009962.transcript.fasta，共 17 条记录。
# 同源组 OG0009972 写入 OG0009972.transcript.fasta，共 16 条记录。
# 同源组 OG0009981 写入 OG0009981.transcript.fasta，共 15 条记录。
# 同源组 OG0009982 写入 OG0009982.transcript.fasta，共 15 条记录。
# 同源组 OG0009992 写入 OG0009992.transcript.fasta，共 16 条记录。
# 同源组 OG0009993 写入 OG0009993.transcript.fasta，共 15 条记录。
# 同源组 OG0009994 写入 OG0009994.transcript.fasta，共 16 条记录。
# 同源组 OG0010009 写入 OG0010009.transcript.fasta，共 15 条记录。
# 同源组 OG0010014 写入 OG0010014.transcript.fasta，共 15 条记录。
# 同源组 OG0010021 写入 OG0010021.transcript.fasta，共 15 条记录。
# 同源组 OG0010026 写入 OG0010026.transcript.fasta，共 17 条记录。
# 同源组 OG0010029 写入 OG0010029.transcript.fasta，共 15 条记录。
# 同源组 OG0010042 写入 OG0010042.transcript.fasta，共 17 条记录。
# 同源组 OG0010043 写入 OG0010043.transcript.fasta，共 15 条记录。
# 同源组 OG0010047 写入 OG0010047.transcript.fasta，共 17 条记录。
# 同源组 OG0010051 写入 OG0010051.transcript.fasta，共 17 条记录。
# 同源组 OG0010054 写入 OG0010054.transcript.fasta，共 15 条记录。
# 同源组 OG0010062 写入 OG0010062.transcript.fasta，共 17 条记录。
# 同源组 OG0010080 写入 OG0010080.transcript.fasta，共 16 条记录。
# 同源组 OG0010084 写入 OG0010084.transcript.fasta，共 16 条记录。
# 同源组 OG0010085 写入 OG0010085.transcript.fasta，共 15 条记录。
# 同源组 OG0010088 写入 OG0010088.transcript.fasta，共 15 条记录。
# 同源组 OG0010089 写入 OG0010089.transcript.fasta，共 15 条记录。
# 同源组 OG0010097 写入 OG0010097.transcript.fasta，共 15 条记录。
# 同源组 OG0010111 写入 OG0010111.transcript.fasta，共 15 条记录。
# 同源组 OG0010122 写入 OG0010122.transcript.fasta，共 15 条记录。
# 同源组 OG0010133 写入 OG0010133.transcript.fasta，共 17 条记录。
# 同源组 OG0010136 写入 OG0010136.transcript.fasta，共 16 条记录。
# 同源组 OG0010158 写入 OG0010158.transcript.fasta，共 15 条记录。
# 同源组 OG0010171 写入 OG0010171.transcript.fasta，共 17 条记录。
# 同源组 OG0010191 写入 OG0010191.transcript.fasta，共 17 条记录。
# 同源组 OG0010230 写入 OG0010230.transcript.fasta，共 16 条记录。
# 同源组 OG0010276 写入 OG0010276.transcript.fasta，共 17 条记录。
# 同源组 OG0010345 写入 OG0010345.transcript.fasta，共 17 条记录。
# 同源组 OG0010363 写入 OG0010363.transcript.fasta，共 16 条记录。
# 同源组 OG0010417 写入 OG0010417.transcript.fasta，共 15 条记录。
# 同源组 OG0010424 写入 OG0010424.transcript.fasta，共 15 条记录。
# 同源组 OG0010517 写入 OG0010517.transcript.fasta，共 15 条记录。
# 同源组 OG0010568 写入 OG0010568.transcript.fasta，共 17 条记录。
# 同源组 OG0010727 写入 OG0010727.transcript.fasta，共 15 条记录。
# 同源组 OG0010785 写入 OG0010785.transcript.fasta，共 15 条记录。
