# %%
coloar <- readRDS("tissue_color_mapping.rds")

# %%
print(coloar)
# Out:
#              Whole_body                    Head               Digestive
#               "#E41A1C"               "#377EB8"               "#984EA3"
#    Developmental_tissue                Fat_body                   Gland
#               "#8DA0CB"               "#4DAF4A"               "#FF7F00"
#                   Ovary                  Testis         Head_and_Thorax
#               "#FFFF33"               "#A65628"               "#F781BF"
#                    Wing                  Muscle                    <NA>
#               "#999999"               "#66C2A5"               "#FC8D62"
#                    <NA>                     Leg                    Pupa
#               "#A6D854"               "#FFD92F"               "#E5C494"
#               Hemolymph                     Egg                  Thorax
#               "#8DD3C7"               "#FFFFB3"               "#BEBADA"
#               Sensillum                  Neuron               Excretory
# ...
